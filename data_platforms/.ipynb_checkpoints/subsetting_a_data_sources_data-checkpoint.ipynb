# %% [markdown]
# <h1 class="header"><img class="logo" src="https://github.com/pazrg/SOCIB_API/raw/master/images/socib_logo.png" width="200px"></h1>

# %% [markdown]
# <h3> STYLING NOTEBOOK (OPTIONAL)</h3>

# %%
from IPython.core.display import HTML
import urllib2
HTML(urllib2.urlopen('https://raw.githubusercontent.com/pazrg/SOCIB_API/master/style/custom/custom.css').read())
# Out:
# <style>
#
# h1{
# 	float:right !important
# }
#
# h1>img{
# 	width: 200px !important
# }
#
# h3{
# 	background-color: #00334C;
# 	border: 1px solid #e3e3e3;
# 	border-radius: 4px;
# 	color: #3dabb6;
# 	padding: 19px
# }
#
# h3>span{
# 	border: 1px solid #3dabb6;
# 	border-radius: 4px;
# 	background-color: #3dabb6;
# 	color: white;
# 	padding: 5px
# }
#
# ul>li>b{
# 	border: 1px solid #3dabb6;
# 	border-radius: 4px;
# 	background-color: #3dabb6;
# 	color: white; padding: 5px;
# }
# </style>

# %% [markdown]
# <h3> HANDY PYTHON PACKAGES </h3>

# %%
import requests
import json
from IPython.display import display, HTML, JSON
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.basemap import Basemap
import shapely
from shapely.geometry import box
from matplotlib.patches import Polygon
from matplotlib import colors
from mpl_toolkits.mplot3d import Axes3D
from json2html import *
from IPython.display import HTML, display
# %matplotlib inline

# %% [markdown]
# <h3> PREREQUISITES </h3>

# %%
api_key = '' #write you SOCIB api_key
api_url = 'http://api.socib.es'
headers = {
    'accept': 'application/vnd.socib+json',
    'api_key': api_key,
}

# %% [markdown]
# As already shown in ['Finding a certain data-source'](https://github.com/pazrg/SOCIB_API/blob/master/data_sources/finding_a_certain_data_source.ipynb), there are parameters that added to an endpoint allows applying some filtering over the generic answer: let's have a look to the ones available for the <b>/data-sources/{id}/data</b> auxiliary endpoint and apply them to the a deployment.

# %% [markdown]
# <h3> REQUESTING A DATA-SOURCE'S DATA <span>WITH PARAMS</span></h3>

# %% [markdown]
# <h3>1. FIND A DATA-SOURCE</h3>

# %% [markdown]
# Setting a certain time range, a defined area, a certain platform type and a certain variable to find a number of matching deployments:

# %%
time_range_start = '2017-07-01T00:00:00' # should match the notation YYYY-MM-DDTHH:MM:SS
time_range_end =  '2018-12-01T00:00:00' # should match the notation YYYY-MM-DDTHH:MM:SS
min_lat = 40.0#float
max_lat = 38.0 #float
min_lon = 0.0 #float
max_lon = 3.0#float
bbox = str(min_lat)+','+str(max_lat)+','+str(min_lon)+','+str(max_lon)
platform_type = 'Research Vessel'
variables = 'sea_water_temperature'

# %%
end_point = '/data-sources/'
url_addons = '?platform_type=%s&initial_datetime=%s&end_datetime=%s&standard_variable=%s&bbox=%s'%(platform_type,time_range_start,time_range_end, variables,bbox)
request = requests.get('%s%s%s' % (api_url, end_point,url_addons), headers=headers)
response = json.loads(request.text)
print('Requested url: '+'%s%s%s' % (api_url, end_point,url_addons))
print(" ")
print('A total of %s SOCIB deployments match the above searching criteria'% (response['count']))
# Out:
# Requested url: http://api.socib.es/data-sources/?platform_type=Research Vessel&initial_datetime=2017-07-01T00:00:00&end_datetime=2018-12-01T00:00:00&standard_variable=sea_water_temperature&bbox=40.0,38.0,0.0,3.0
#
# A total of 14 SOCIB deployments match the above searching criteria

# %% [markdown]
# And choosing one of the above deployments, let's have a look to its metadata:

# %%
targeted_deployment = response['results'][2]#i.e deployment/data-source number 2 of the above page
metadata = {k:v for k, v in targeted_deployment.items() if k != 'entries'} #skipping the deployment data for later
HTML(json2html.convert(json=metadata))
# Out:
# <table border="1"><tr><th>status</th><td>completed</td></tr><tr><th>description</th><td>CTD observational data</td></tr><tr><th>data_type</th><td>Trajectory profile</td></tr><tr><th>platform</th><td><table border="1"><tr><th>is_active</th><td>False</td></tr><tr><th>type</th><td>Research Vessel</td></tr><tr><th>name</th><td>Garcia_del_Cid_RV</td></tr></table></td></tr><tr><th>processing_levels</th><td><table border="1"><tr><th>L1_corr</th><td><table border="1"><tr><th>variables</th><td><ul><li>downwelling_photosynthetic_photon_flux_in_sea_water</li><li>sea_water_electrical_conductivity</li><li>mass_concentration_of_chlorophyll_in_sea_water</li><li>sea_water_pressure</li><li>turbidity_of_sea_water</li><li>sea_water_practical_salinity</li><li>volume_beam_attenuation_coefficient_of_radiative_flux_in_sea_water</li><li>mass_concentration_of_oxygen_in_sea_water</li><li>sea_water_temperature</li></ul></td></tr></table></td></tr><tr><th>L0</th><td><table border="1"><tr><th>variables</th><td><
# ...

# %% [markdown]
# <h3>2. REQUEST ITS DATA</h3>

# %% [markdown]
# Let's choose one of the above L1 variables by means of <b>/data-sources/{id}/data/ </b> auxiliary endpoint:

# %%
end_point_plus_aux = '/data-sources/'+targeted_deployment['id']+'/data/?processing_level=L1&standard_variable=sea_water_temperature'
request = requests.get('%s%s' % (api_url, end_point_plus_aux), headers=headers)
response = json.loads(request.text)
print('Requested url: '+'%s%s' % (api_url, end_point_plus_aux))
# Out:
# Requested url: http://api.socib.es/data-sources/02f2600d3c/data/?processing_level=L1&standard_variable=sea_water_temperature

# %%
for level in response.keys():
    variables_metadata = [{response[level]['features'][feature]['feature_type']: [{standard_variable: [{k:v for k, v in response[level]['features'][feature]['variables'][standard_variable][param].items() if k!='data'} for param in response[level]['features'][feature]['variables'][standard_variable].keys()]} for standard_variable in response[level]['features'][feature]['variables']]} for feature in range(0,len(response[level]['features']))]
    variables_per_level = {level: variables_metadata}
    display(HTML(json2html.convert(json=variables_per_level)))
# Out:
# <table border="1"><tr><th>L1</th><td><table border="1"><tr><th>trajectoryProfileIrregular</th></tr><tr><td><table border="1"><tr><th>sea_water_temperature</th></tr><tr><td><table border="1"><tr><th>axis_y_name</th><th>axis_z_name</th><th>axis_x_name</th><th>precision</th><th>axis_t_name</th><th>long_name</th><th>standard_name</th><th>units</th></tr><tr><td>latitude</td><td>depth</td><td>longitude</td><td>0.0001</td><td>time</td><td>Sea water temperature</td><td>sea_water_temperature</td><td>C</td></tr></table></td></tr></table></td></tr></table></td></tr></table>

# %% [markdown]
# <h3>3. PLOT ITS DATA</h3>

# %% [markdown]
# Let's have an quick overview of the complete deployment:

# %%
def get_variable_matches(response, standard_name, level_type, feature_type):
    # explore a given /data-source/{id}/data/ response looking for a variable with a specific standard name,processing level and feature type
    level = response[level_type]
    features = [feature for feature in level['features'] if feature['feature_type'] == feature_type]
    variables = [feature['variables'][standard_name] for feature in features if standard_name in feature['variables'].keys()]
    matches = []
    for param in variables:
        for key in param.keys():
            try:
                matches.append({'units':param[key]['units'], 'data': param[key]['data']})
            except:
                matches.append({'units':'unknown', 'data': param[key]['data']})
    return matches;

# %%
def get_coordinate(response, name, level_type, feature_type):
    # explore a given /data-source/{id}/data/ response looking for a coordinate with a specific standard name,processing level and feature type
    level = response[level_type]
    features = [feature for feature in level['features'] if feature['feature_type'] == feature_type]
    coords = [feature['coordinates'][name] for feature in features if name in feature['coordinates'].keys()]
    matches = []
    for param in coords:
        try:
            matches.append({'units':param['units'], 'data': param['data']})
        except:
            matches.append({'units': 'unknown', 'data': param['data']})    
    return matches;

# %%
variable_name = 'sea_water_temperature'
coord_name_1 = 'latitude'
coord_name_2 = 'longitude'
coord_name_3 = 'time'
coord_name_4 = 'depth'

# %%
var = get_variable_matches(response, variable_name, 'L1', 'trajectoryProfileIrregular')[0]
lat = get_coordinate(response, coord_name_1, 'L1','trajectoryProfileIrregular' )[0]
lon = get_coordinate(response, coord_name_2, 'L1', 'trajectoryProfileIrregular')[0]
time = get_coordinate(response, coord_name_3, 'L1','trajectoryProfileIrregular')[0]
depth = get_coordinate(response, coord_name_4, 'L1', 'trajectoryProfileIrregular')[0]

# %%
lat = np.array(lat['data'],dtype=float)
lon = np.array(lon['data'],dtype=float)
depth = np.array(depth['data'],dtype=float)
time = time['data']

# %%
fig = plt.figure(figsize=(8,8))
ax = plt.subplot(111)
plt.plot(lon, lat, 'ko', ms=3)
plt.text(lon[0], lat[0], 'Start', fontsize=16)
plt.text(lon[-1], lat[-1], 'End', fontsize=16)
plt.show()

# %%
lonmin, lonmax = ax.get_xlim()
latmin, latmax = ax.get_ylim()
cmap = plt.cm.Spectral_r
norm = colors.Normalize(vmin=min(var['data'][0]), vmax=max(var['data'][0]))

# %%
fig = plt.figure(figsize=(20,20))

ax = fig.add_subplot(222, projection='3d')
for a in range(0, len(time)-1):
    plt.scatter(lon[a]*np.ones(len(depth[0])),lat[a]*np.ones(len(depth[0])), zs=-depth[a,:], zdir='z', s=20, c=var['data'][a], edgecolor='None', cmap=cmap, norm=norm)
    plt.tick_params(labelsize=20)
cb = plt.colorbar(fraction=0.040, cmap=cmap, norm=norm)
cb.ax.tick_params(labelsize=20) 
cb.set_label(label="TEMP", size=20)
ax.set_zlabel('depth',labelpad=-40,rotation=90,fontsize=20)
ax.set_ylabel('lat',labelpad=20,fontsize=20)
ax.set_xlabel('lon',labelpad=20,fontsize=20)

ax = fig.add_subplot(221)
m = Basemap(projection='merc', llcrnrlat=min(lat)-5, urcrnrlat=max(lat)+5,llcrnrlon=min(lon)-5, urcrnrlon=max(lon)+5, lat_ts=38., resolution='i')
m.fillcontinents(zorder=2)
m.drawparallels(np.arange(-90.,91.,2.), labels=[1,0,0,0], linewidth=0.5, zorder=1, fontsize=20)
m.drawmeridians(np.arange(-180.,181.,3.), labels=[0,0,1,0], linewidth=0.5, zorder=1, fontsize=20)
x,y = m(lon, lat)
m.plot(x,y, 'ro-', ms=5)

ax = fig.add_subplot(212)
bounding_box = shapely.geometry.box(lonmin, latmin, lonmax, latmax)
x = bounding_box.centroid.x
y = bounding_box.centroid.y
map = Basemap(projection='ortho',lat_0=y, lon_0=x,resolution='i')
map.drawmapboundary()
map.fillcontinents()
map.drawcoastlines()
xs = [lonmin,lonmax,lonmax,lonmin,lonmin]
ys = [latmin,latmin,latmax,latmax,latmin]
map.plot(xs, ys,latlon = True, color='red')

plt.show()

# %% [markdown]
# <h3>3. SUBSET ITS DATA</h3>

# %% [markdown]
# The next query parameters are available for subsetting the above generic answer of the <b>/data-sources/{id}/data/</b> endpoint:

# %% [markdown]
# <ul><li><h3>REQUESTING A DATA-SOURCE'S DATA BY <span>TIME-RANGE</span></h3></li></ul>

# %% [markdown]
# From the step number 1 we know the whole time range covered by the deployment:

# %%
end_point = '/data-sources/'+targeted_deployment['id']
request = requests.get('%s%s' % (api_url, end_point), headers=headers)
response = json.loads(request.text)
print('Requested url: '+'%s%s. Be aware of the id.' % (api_url, end_point))
# Out:
# Requested url: http://api.socib.es/data-sources/02f2600d3c. Be aware of the id.

# %%
metadata = {k:v for k, v in response.items() if k == 'initial_datetime' or k == 'end_datetime'}
HTML(json2html.convert(json=metadata))
# Out:
# <table border="1"><tr><th>initial_datetime</th><td>2018-05-06T02:16:39Z</td></tr><tr><th>end_datetime</th><td>2018-05-16T15:24:19Z</td></tr></table>

# %% [markdown]
#  Let's keep only the first day of data:

# %%
targeted_initial_datetime = targeted_deployment['initial_datetime'].split('T')[0]+'T00:00:00'
targeted_end_datetime = targeted_deployment['initial_datetime'].split('T')[0]+'T23:59:59'
print('targeted_initial_datetime: '+ targeted_deployment['initial_datetime'])
print('targeted_end_datetime: '+ targeted_deployment['end_datetime'])
# Out:
# targeted_initial_datetime: 2018-05-06T02:16:39Z
# targeted_end_datetime: 2018-05-16T15:24:19Z

# %%
end_point_plus_aux = '/data-sources/'+targeted_deployment['id']+'/data/'
url_addons = '?initial_datetime=%s&end_datetime=%s'%(targeted_initial_datetime,targeted_end_datetime)
request = requests.get('%s%s%s' % (api_url, end_point_plus_aux, url_addons), headers=headers)
response = json.loads(request.text)
print('Requested url: '+'%s%s%s' % (api_url, end_point_plus_aux, url_addons))
# Out:
# Requested url: http://api.socib.es/data-sources/02f2600d3c/data/?initial_datetime=2018-05-06T00:00:00&end_datetime=2018-05-06T23:59:59

# %% [markdown]
# Let's have a look to the resulting subset:

# %%
var = get_variable_matches(response, variable_name, 'L1', 'trajectoryProfileIrregular')
lat = get_coordinate(response, coord_name_1, 'L1','trajectoryProfileIrregular')
lon = get_coordinate(response, coord_name_2, 'L1', 'trajectoryProfileIrregular')
time = get_coordinate(response, coord_name_3, 'L1','trajectoryProfileIrregular')
depth = get_coordinate(response, coord_name_4, 'L1', 'trajectoryProfileIrregular')

# %%
lat = np.array(lat[0]['data'],dtype=float)
lon = np.array(lon[0]['data'],dtype=float)
depth = np.array(depth[0]['data'],dtype=float)
time = time[0]['data']

# %%
fig = plt.figure(figsize=(8,8))
ax = plt.subplot(111)
plt.plot(lon, lat, 'ko', ms=3)
plt.text(lon[0], lat[0], 'Start', fontsize=16)
plt.text(lon[-1], lat[-1], 'End', fontsize=16)
plt.show()

# %%
lonmin, lonmax = ax.get_xlim()
latmin, latmax = ax.get_ylim()
cmap = plt.cm.Spectral_r
norm = colors.Normalize(vmin=min(var[0]['data'][0]), vmax=max(var[0]['data'][0]))

# %%
fig = plt.figure(figsize=(20,20))

ax = fig.add_subplot(222, projection='3d')
for a in range(0, len(time)-1):
    plt.scatter(lon[a]*np.ones(len(depth[0])),lat[a]*np.ones(len(depth[0])), zs=-depth[a,:], zdir='z', s=20, c=var[0]['data'][a], edgecolor='None', cmap=cmap, norm=norm)
    plt.tick_params(labelsize=20)
cb = plt.colorbar(fraction=0.040, cmap=cmap, norm=norm)
cb.ax.tick_params(labelsize=20) 
cb.set_label(label="TEMP", size=20)
ax.set_zlabel('depth',labelpad=-40,rotation=90,fontsize=20)
ax.set_ylabel('lat',labelpad=20,fontsize=20)
ax.set_xlabel('lon',labelpad=20,fontsize=20)

ax = fig.add_subplot(221)
m = Basemap(projection='merc', llcrnrlat=min(lat)-5, urcrnrlat=max(lat)+5,llcrnrlon=min(lon)-5, urcrnrlon=max(lon)+5, lat_ts=38., resolution='i')
m.fillcontinents(zorder=2)
m.drawparallels(np.arange(-90.,91.,2.), labels=[1,0,0,0], linewidth=0.5, zorder=1, fontsize=20)
m.drawmeridians(np.arange(-180.,181.,3.), labels=[0,0,1,0], linewidth=0.5, zorder=1, fontsize=20)
x,y = m(lon, lat)
m.plot(x,y, 'ro-', ms=5)

plt.show()

# %% [markdown]
# <ul><li><h3>REQUESTING A DATA-SOURCE'S DATA BY <span>BOUNDING-BOX</span></h3></li></ul>

# %% [markdown]
# From the step number 1 we know the whole area covered by the deployment:

# %%
end_point = '/data-sources/'+targeted_deployment['id']
request = requests.get('%s%s' % (api_url, end_point), headers=headers)
response = json.loads(request.text)
print('Requested url: '+'%s%s. Be aware of the id.' % (api_url, end_point))
# Out:
# Requested url: http://api.socib.es/data-sources/02f2600d3c. Be aware of the id.

# %%
metadata = {k:v for k, v in response.items() if k == 'coverage_bounding_box'}
HTML(json2html.convert(json=metadata))
# Out:
# <table border="1"><tr><th>coverage_bounding_box</th><td><table border="1"><tr><th>type</th><td>Polygon</td></tr><tr><th>coordinates</th><td><ul><li><ul><li><ul><li>2.2643</li><li>38.04283</li></ul></li><li><ul><li>2.2643</li><li>38.89417</li></ul></li><li><ul><li>3.4835</li><li>38.89417</li></ul></li><li><ul><li>3.4835</li><li>38.04283</li></ul></li><li><ul><li>2.2643</li><li>38.04283</li></ul></li></ul></li></ul></td></tr></table></td></tr></table>

# %% [markdown]
# Let's think we are interested in the data recovered in one of the corners of the total area covered by the deployment:

# %%
min_lat = 30.80#float
max_lat = 40.0 #float
min_lon = 3.1 #float
max_lon = 3.4#float
bbox = str(min_lat)+','+str(max_lat)+','+str(min_lon)+','+str(max_lon)

# %%
end_point_plus_aux = '/data-sources/'+targeted_deployment['id']+'/data/'
url_addons = '?bbox=%s'%(bbox)
request = requests.get('%s%s%s' % (api_url, end_point_plus_aux, url_addons), headers=headers)
response = json.loads(request.text)
print('Requested url: '+'%s%s%s' % (api_url, end_point_plus_aux, url_addons))
# Out:
# Requested url: http://api.socib.es/data-sources/02f2600d3c/data/?bbox=30.8,40.0,3.1,3.4

# %% [markdown]
# Let's have a look to the subset:'

# %%
var = get_variable_matches(response, variable_name, 'L1', 'trajectoryProfileIrregular')[0]
lat = get_coordinate(response, coord_name_1, 'L1','trajectoryProfileIrregular')[0]
lon = get_coordinate(response, coord_name_2, 'L1', 'trajectoryProfileIrregular')[0]
time = get_coordinate(response, coord_name_3, 'L1','trajectoryProfileIrregular')[0]
depth = get_coordinate(response, coord_name_4, 'L1', 'trajectoryProfileIrregular')[0]

# %%
lat = np.array(lat['data'],dtype=float)
lon = np.array(lon['data'],dtype=float)
depth = np.array(depth['data'],dtype=float)
time = time['data']

# %%
fig = plt.figure(figsize=(8,8))
ax = plt.subplot(111)
plt.plot(lon, lat, 'ko', ms=3)
plt.text(lon[0], lat[0], 'Start', fontsize=16)
plt.text(lon[-1], lat[-1], 'End', fontsize=16)
plt.show()

# %%
lonmin, lonmax = ax.get_xlim()
latmin, latmax = ax.get_ylim()
cmap = plt.cm.Spectral_r
norm = colors.Normalize(vmin=min(var['data'][0]), vmax=max(var['data'][0]))

# %%
fig = plt.figure(figsize=(20,20))

ax = fig.add_subplot(222, projection='3d')
for a in range(0, len(time)-1):
    plt.scatter(lon[a]*np.ones(len(depth[0])),lat[a]*np.ones(len(depth[0])), zs=-depth[a,:], zdir='z', s=20, c=var['data'][a], edgecolor='None', cmap=cmap, norm=norm)
    plt.tick_params(labelsize=20)
cb = plt.colorbar(fraction=0.040, cmap=cmap, norm=norm)
cb.ax.tick_params(labelsize=20) 
cb.set_label(label="TEMP", size=20)
ax.set_zlabel('depth',labelpad=-40,rotation=90,fontsize=20)
ax.set_ylabel('lat',labelpad=20,fontsize=20)
ax.set_xlabel('lon',labelpad=20,fontsize=20)

ax = fig.add_subplot(221)
m = Basemap(projection='merc', llcrnrlat=min(lat)-5, urcrnrlat=max(lat)+5,llcrnrlon=min(lon)-5, urcrnrlon=max(lon)+5, lat_ts=38., resolution='i')
m.fillcontinents(zorder=2)
m.drawparallels(np.arange(-90.,91.,2.), labels=[1,0,0,0], linewidth=0.5, zorder=1, fontsize=20)
m.drawmeridians(np.arange(-180.,181.,3.), labels=[0,0,1,0], linewidth=0.5, zorder=1, fontsize=20)
x,y = m(lon, lat)
m.plot(x,y, 'ro-', ms=5)

plt.show()

# %% [markdown]
# <ul><li><h3>REQUESTING A DATA-SOURCE'S DATA BY <span>ELEVATION-RANGE</span></h3></li></ul>

# %%
min_elevation = -100.0
max_elevation = 0
elevation = str(min_elevation)+','+str(max_elevation)

# %%
end_point_plus_aux = '/data-sources/'+targeted_deployment['id']+'/data/'
url_addons = '?elevation_range=%s'%(elevation)
request = requests.get('%s%s%s' % (api_url, end_point_plus_aux, url_addons), headers=headers)
response = json.loads(request.text)
print('Requested url: '+'%s%s%s' % (api_url, end_point_plus_aux, url_addons))
# Out:
# Requested url: http://api.socib.es/data-sources/02f2600d3c/data/?elevation_range=-100.0,0

# %%
var = get_variable_matches(response, variable_name, 'L1', 'trajectoryProfileIrregular')[0]
lat = get_coordinate(response, coord_name_1, 'L1','trajectoryProfileIrregular')[0]
lon = get_coordinate(response, coord_name_2, 'L1', 'trajectoryProfileIrregular')[0]
time = get_coordinate(response, coord_name_3, 'L1','trajectoryProfileIrregular')[0]
depth = get_coordinate(response, coord_name_4, 'L1', 'trajectoryProfileIrregular')[0]

# %%
lat = np.array(lat['data'],dtype=float)
lon = np.array(lon['data'],dtype=float)
depth = np.array(depth['data'],dtype=float)
time = time['data']

# %% [markdown]
# Let's have a look to the subset:

# %%
lonmin, lonmax = ax.get_xlim()
latmin, latmax = ax.get_ylim()
cmap = plt.cm.Spectral_r
norm = colors.Normalize(vmin=min(var['data'][0]), vmax=max(var['data'][0]))

# %%
fig = plt.figure(figsize=(20,20))

ax = fig.add_subplot(222, projection='3d')
for a in range(0, len(time)-1):
    plt.scatter(lon[a]*np.ones(len(depth[0])),lat[a]*np.ones(len(depth[0])), zs=-depth[a,:], zdir='z', s=20, c=var['data'][a], edgecolor='None', cmap=cmap, norm=norm)
    plt.tick_params(labelsize=20)
cb = plt.colorbar(fraction=0.040, cmap=cmap, norm=norm)
cb.ax.tick_params(labelsize=20) 
cb.set_label(label="TEMP", size=20)
ax.set_zlabel('depth',labelpad=-40,rotation=90,fontsize=20)
ax.set_ylabel('lat',labelpad=20,fontsize=20)
ax.set_xlabel('lon',labelpad=20,fontsize=20)

ax = fig.add_subplot(221)
m = Basemap(projection='merc', llcrnrlat=min(lat)-5, urcrnrlat=max(lat)+5,llcrnrlon=min(lon)-5, urcrnrlon=max(lon)+5, lat_ts=38., resolution='i')
m.fillcontinents(zorder=2)
m.drawparallels(np.arange(-90.,91.,2.), labels=[1,0,0,0], linewidth=0.5, zorder=1, fontsize=20)
m.drawmeridians(np.arange(-180.,181.,3.), labels=[0,0,1,0], linewidth=0.5, zorder=1, fontsize=20)
x,y = m(lon, lat)
m.plot(x,y, 'ro-', ms=5)

plt.show()

# %% [markdown]
# <h3> WHAT ELSE?</h3>

# %% [markdown]
# <ul>
# <li><b>RESAMPLING A DATA-SOURCE'S DATA</b> <br><br>If you want to know more about how to resample a given data-source's data overlooking the netCDF format, please have a look at the [Example 5](https://github.com/pazrg/SOCIB_API/blob/master/data_sources/subsetting_a_data_source_data.ipynb) ('Resampling a data-source's data'), where it is explained how to use query parameters over the API auxiliary endpoints to resample a deployments data.</li>
# </ul>
