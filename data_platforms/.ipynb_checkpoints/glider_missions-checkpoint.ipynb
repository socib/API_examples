# %% [markdown]
# <h3> HANDY PYTHON PACKAGES </h3>

# %%
import requests
import json
from random import randint
import pandas as pd
from IPython.display import display
from collections import Counter

# %% [markdown]
# <H3> PREREQUISITES</H3>

# %%
api_key = '' #write you SOCIB api_key
api_url = 'http://api.socib.es'
headers = {
    'accept': 'application/vnd.socib+json',
    'api_key': api_key,
}

# %% [markdown]
# <h3>AUXILIARY FUNCTIONS</h3>

# %%
def params_concatenation(params, values):
    """
    Concatenates the params and their values in an unique string to later be attached to the generic API ENDPOINTS
    """
    params_concatenation = ''
    for param, value in zip(params,values):
        if params.index(param) != len(PARAMS)-1:
            params_concatenation = params_concatenation + param+'='+value+'&'
        else:
            params_concatenation = params_concatenation + param+'='+value
    return params_concatenation;

# %% [markdown]
# <h3> DATA-PRODUCTS ENDPOINT </h3>

# %% [markdown]
# SOCIB Data-products can either be isolated deployments (equivalent for data-sources when so) or, a group of deployments that share some context becuase they were concurrent (multiplatform monitoring operations) or recurrent(long-term monitoring operations) deployments.
#
# Some examples of these are the so called glider-missions, oceanographic campaings, fixed-stations etc. On those cases, the focus is on retrieveing data continously from an specific area, track or point no matter how many deployments have been done to ensure this. Deployments becomes secondary and there so grouping them in major entities becomes handy.
#
# As we already saw in Quick start there is an ENDPOINT that allows users to dive into all the data-products that SOCIB has composed:

# %%
end_point = '/data-products/'
request = requests.get('%s%s' % (api_url, end_point), headers=headers)
response = json.loads(request.text)

print('Requested url: '+'%s%s' % (api_url, end_point))
print(' ')
print('SOCIB has composed so far a total of %s data-products out of deployments'%(response['count']))
# Out:
# Requested url: http://api.socib.es/data-products/
#
# SOCIB has composed so far a total of 159 data-products out of deployments

# %% [markdown]
# Choosing randomly one of the above data-products:

# %%
random = randint(0,response['count']-1) #random deployment
print(random)
# Out:
# 25

# %%
random = 25
page = random/8+1
item = (random - (random/8)*8)-1
print('Data-product number %s is on page %s at position %s'%(random,page,item))
# Out:
# Data-product number 25 is on page 4 at position 0

# %%
#requesting the page where the deployment is
end_point = '/data-products/'
random_request = requests.get('%s%s?%s' % (api_url, end_point, 'page='+str(page)), headers=headers)
random_response = json.loads(random_request.text)
print('Requested url: '+'%s%s?%s' % (api_url, end_point, 'page='+str(page)))
print('')
print('Data-product on page %s at position %s is described by at least 3 properties:'%(page,item))
#selecting inside this page the desired product
random_product = random_response['results'][item] 
df = pd.DataFrame(random_product.values(), index=random_product.keys(), columns=['data product '+str(random)]).transpose()
display(df.style)
# Out:
# Requested url: http://api.socib.es/data-products/?page=4
#
# Data-product on page 4 at position 0 is described by at least 3 properties:
#         <style  type="text/css" >
#
#
#         </style>
#
#         <table id="T_f7eb3b44_101b_11e8_aae1_64006a8d5c4b" None>
#
#
#         <thead>
#
#             <tr>
#
#
#                 <th class="blank level0" >
#
#
#
#
#                 <th class="col_heading level0 col0" colspan=1>
#                   description
#
#
#
#                 <th class="col_heading level0 col1" colspan=1>
#                   id
#
#
#
#                 <th class="col_heading level0 col2" colspan=1>
#                   name
#
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#
#                 <th id="T_f7eb3b44_101b_11e8_aae1_64006a8d5c4b"
#                  class="row_heading level0 row0" rowspan=1>
#                     data product 25
#
#
#
#                 <td id="T_f7eb3b44_101b_11e8_aae1_64006a8d5c4brow0_col0"
#                  class="data row0 col0" >
#                     Canales cruise, defined and followed by SOCIB (with in kind collaboration of IMEDEA-CSIC) to implement the inter-annual monitoring endurance line (ENL1) covering the Balearic channels of Mallorca and EĂŻvissa during the year 2017. The list of waypoints conforming this cruise stand as the default set for all the canales missions for the campaign of 2017; nevertheless, slightly modifications may be applied under special circumstances.
#
#
#
#                 <td id="T_f7eb3b44_101b_11e8_aae1_64006a8d5c4brow0_col1"
#                  class="data row0 col1" >
#                     glider-canales2017
#
#
#
#                 <td id="T_f7eb3b44_101b_11e8_aae1_64006a8d5c4brow0_col2"
#                  class="data row0 col2" >
#                     glider canales2017
#
#
#             </tr>
#
#         </tbody>
#         </table>

# %% [markdown]
# Knowing a given product id it is also possible to access the above information and even more with the DATA-PRODUCTS/ID/ ENDPOINT:

# %%
detailed_end_point = '/data-products/'+random_product['id'] 
detailed_request = requests.get('%s%s' % (api_url, detailed_end_point), headers=headers)
detailed_response = json.loads(detailed_request.text)
print('Requested url: '+'%s%s' % (api_url, detailed_end_point))
values = []
for val in detailed_response.values():
    if type(val) is list:
        ids = []
        for deployment in val:
            ids.append(deployment['id'])
        values.append(', '.join(ids))
    else:
        values.append(val)
df = pd.DataFrame(values, index=[['data-sources ids']+detailed_response.keys()[1:len(detailed_response.keys())]], columns=['data product '+str(random)]).transpose()
display(df.style)  
print('From sources, it is understood that the above product is composed by %s deployments or data-sources'%(len(ids)))
# Out:
# Requested url: http://api.socib.es/data-products/glider-canales2017
#         <style  type="text/css" >
#
#
#         </style>
#
#         <table id="T_fbd513d8_101b_11e8_aae1_64006a8d5c4b" None>
#
#
#         <thead>
#
#             <tr>
#
#
#                 <th class="blank level0" >
#
#
#
#
#                 <th class="col_heading level0 col0" colspan=1>
#                   data-sources ids
#
#
#
#                 <th class="col_heading level0 col1" colspan=1>
#                   description
#
#
#
#                 <th class="col_heading level0 col2" colspan=1>
#                   id
#
#
#
#                 <th class="col_heading level0 col3" colspan=1>
#                   name
#
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#
#                 <th id="T_fbd513d8_101b_11e8_aae1_64006a8d5c4b"
#                  class="row_heading level0 row0" rowspan=1>
#                     data product 25
#
#
#
#                 <td id="T_fbd513d8_101b_11e8_aae1_64006a8d5c4brow0_col0"
#                  class="data row0 col0" >
#                     c5260f9b8a, 4dd1476b27, a95b4e2fc0, 0fe811ec23, ff1beefdcf, 8391000e12, 5016ab2004, 46d0753ab5, 3ad5833bb0, ccf61fcf8b, 9f7b978fc7, 7c2cc2b816, b81632491f, af67f96203
#
#
#
#                 <td id="T_fbd513d8_101b_11e8_aae1_64006a8d5c4brow0_col1"
#                  class="data row0 col1" >
#                     Canales cruise, defined and followed by SOCIB (with in kind collaboration of IMEDEA-CSIC) to implement the inter-annual monitoring endurance line (ENL1) covering the Balearic channels of Mallorca and EĂŻvissa during the year 2017. The list of waypoints conforming this cruise stand as the default set for all the canales missions for the campaign of 2017; nevertheless, slightly modifications may be applied under special circumstances.
#
#
#
#                 <td id="T_fbd513d8_101b_11e8_aae1_64006a8d5c4brow0_col2"
#                  class="data row0 col2" >
#                     glider-canales2017
#
#
#
#                 <td id="T_fbd513d8_101b_11e8_aae1_64006a8d5c4brow0_col3"
#                  class="data row0 col3" >
#                     glider canales2017
#
#
#             </tr>
#
#         </tbody>
#         </table>
# From sources, it is understood that the above product is composed by 14 deployments or data-sources

# %% [markdown]
# Nevertheless, special care has to be taken when reading the above number of deployments when it comes to gliders. In general, all SOCIB deployments (platform&instruments ensemble) produce data as they operate and that is: only one type of data is to be delivered when querying a deployment data. SOCIB gliders produce 3 types of data as they operates: Glider real time observational data ("RT"), Glider tracking observational data ("Trajectory") and Glider delayed time observational data ("DT"). While the RT and Trajectory data are produced while the deployment is active, the DT is only available when the deployment is completed and has been recovered.
#
# The transmition of data from gliders has to be done at surface but, while in surface, gliders are exposed to posible collisions and are prevented from retrieveing data from the water column. Reducing the time at surface is then quite attractive. The critical point to do this is how time-consuming result sending data once emerged: sending just 80K of data takes 15-20min (via Iridium). On average SOCIB gliders recover up to 3000K of data between dives (6 hours under water), but transmitting this amount of data would keep them on surface during 16h at least. This is not feasible. This is why, the whole data colleted during a deployment is only provided once completed and why only partial (RT) or light (trajectory) data is produced while active.
#
# This way, the above number are not referring deployments (platform&instrument ensemble) perse but the different combinations of deployment and its associated type of data.

# %% [markdown]
# Let then dig more into those suposely 14 'deployments'. As we know from <a href="https://github.com/pazrg/SOCIB_API/blob/master/data_sources/finding_your_data_source.ipynb" target="_blank">finding_your_data_source</a>, every data-source is defined by a 14 properties:

# %%
print('Each deployment is defined by %s properties:' %(len(detailed_response['sources'][0].keys())))
for prop in detailed_response['sources'][0].keys():
    print('    '+prop)
# Out:
# Each deployment is defined by 14 properties:
#     status
#     description
#     data_type
#     instrument
#     processing_levels
#     platform
#     update_datetime
#     initial_datetime
#     end_datetime
#     entries
#     coverage_bounding_box
#     type
#     id
#     name

# %% [markdown]
# Let's just access some of them to know what are we looking at:

# %%
props = ['description','data_type','instrument','platform','initial_datetime','end_datetime']

# %%
array = []
ids = []
for val in detailed_response.values():
    if type(val) is list:
        for deployment in val:
            values = []
            for key in deployment.keys():
                if key in props:
                    values.append(deployment[key])
            array.append(values)
            ids.append(deployment['id'])
df = pd.DataFrame(array, index=ids, columns=props)
display(df.style)
# Out:
#         <style  type="text/css" >
#
#
#         </style>
#
#         <table id="T_ea962d5e_e01a_11e7_8692_64006a8d5c4b" None>
#
#
#         <thead>
#
#             <tr>
#
#
#                 <th class="blank level0" >
#
#
#
#
#                 <th class="col_heading level0 col0" colspan=1>
#                   description
#
#
#
#                 <th class="col_heading level0 col1" colspan=1>
#                   data_type
#
#
#
#                 <th class="col_heading level0 col2" colspan=1>
#                   instrument
#
#
#
#                 <th class="col_heading level0 col3" colspan=1>
#                   platform
#
#
#
#                 <th class="col_heading level0 col4" colspan=1>
#                   initial_datetime
#
#
#
#                 <th class="col_heading level0 col5" colspan=1>
#                   end_datetime
#
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#
#                 <th id="T_ea962d5e_e01a_11e7_8692_64006a8d5c4b"
#                  class="row_heading level0 row0" rowspan=1>
#                     c5260f9b8a
#
#
#
#                 <td id="T_ea962d5e_e01a_11e7_8692_64006a8d5c4brow0_col0"
#                  class="data row0 col0" >
#                     Glider real time observational data
#
#
#
#                 <td id="T_ea962d5e_e01a_11e7_8692_64006a8d5c4brow0_col1"
#                  class="data row0 col1" >
#                     Trajectory
#
#
#
#                 <td id="T_ea962d5e_e01a_11e7_8692_64006a8d5c4brow0_col2"
#                  class="data row0 col2" >
#                     {u'type': {u'type': u'AUV', u'name': u'Glider'}, u'id': 568, u'name': u'SCB-SLDEEP004'}
#
#
#
#                 <td id="T_ea962d5e_e01a_11e7_8692_64006a8d5c4brow0_col3"
#                  class="data row0 col3" >
#                     {u'type': {u'type': u'AUV', u'name': u'Glider'}, u'id': 290, u'name': u'sdeep04'}
#
#
#
#                 <td id="T_ea962d5e_e01a_11e7_8692_64006a8d5c4brow0_col4"
#                  class="data row0 col4" >
#                     2017-09-13T10:35:56Z
#
#
#
#                 <td id="T_ea962d5e_e01a_11e7_8692_64006a8d5c4brow0_col5"
#                  class="data row0 col5" >
#                     2017-10-24T03:45:33Z
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_ea962d5e_e01a_11e7_8692_64006a8d5c4b"
#                  class="row_heading level0 row1" rowspan=1>
#                     4dd1476b27
#
#
#
#                 <td id="T_ea962d5e_e01a_11e7_8692_64006a8d5c4brow1_col0"
#                  class="data row1 col0" >
#                     Glider tracking observational data
#
#
#
#                 <td id="T_ea962d5e_e01a_11e7_8692_64006a8d5c4brow1_col1"
#                  class="data row1 col1" >
#                     Trajectory
#
#
#
#                 <td id="T_ea962d5e_e01a_11e7_8692_64006a8d5c4brow1_col2"
#                  class="data row1 col2" >
#                     {u'type': {u'type': u'AUV', u'name': u'Glider'}, u'id': 568, u'name': u'SCB-SLDEEP004'}
#
#
#
#                 <td id="T_ea962d5e_e01a_11e7_8692_64006a8d5c4brow1_col3"
#                  class="data row1 col3" >
#                     {u'type': {u'type': u'AUV', u'name': u'Glider'}, u'id': 290, u'name': u'sdeep04'}
#
#
#
#                 <td id="T_ea962d5e_e01a_11e7_8692_64006a8d5c4brow1_col4"
#                  class="data row1 col4" >
#                     2017-09-13T10:02:26Z
#
#
#
#                 <td id="T_ea962d5e_e01a_11e7_8692_64006a8d5c4brow1_col5"
#                  class="data row1 col5" >
#                     2017-10-24T04:02:16Z
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_ea962d5e_e01a_11e7_8692_64006a8d5c4b"
#                  class="row_heading level0 row2" rowspan=1>
#                     a95b4e2fc0
#
#
#
#                 <td id="T_ea962d5e_e01a_11e7_8692_64006a8d5c4brow2_col0"
#                  class="data row2 col0" >
#                     Glider real time observational data
#
#
#
#                 <td id="T_ea962d5e_e01a_11e7_8692_64006a8d5c4brow2_col1"
#                  class="data row2 col1" >
#                     Trajectory
#
#
#
#                 <td id="T_ea962d5e_e01a_11e7_8692_64006a8d5c4brow2_col2"
#                  class="data row2 col2" >
#                     {u'type': {u'type': u'AUV', u'name': u'Glider'}, u'id': 568, u'name': u'SCB-SLDEEP004'}
#
#
#
#                 <td id="T_ea962d5e_e01a_11e7_8692_64006a8d5c4brow2_col3"
#                  class="data row2 col3" >
#                     {u'type': {u'type': u'AUV', u'name': u'Glider'}, u'id': 290, u'name': u'sdeep04'}
#
#
#
#                 <td id="T_ea962d5e_e01a_11e7_8692_64006a8d5c4brow2_col4"
#                  class="data row2 col4" >
#                     2017-07-28T17:49:21Z
#
#
#
#                 <td id="T_ea962d5e_e01a_11e7_8692_64006a8d5c4brow2_col5"
#                  class="data row2 col5" >
#                     2017-08-19T05:47:49Z
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_ea962d5e_e01a_11e7_8692_64006a8d5c4b"
#                  class="row_heading level0 row3" rowspan=1>
#                     0fe811ec23
#
#
#
#                 <td id="T_ea962d5e_e01a_11e7_8692_64006a8d5c4brow3_col0"
#                  class="data row3 col0" >
#                     Glider delayed time observational data
#
#
#
#                 <td id="T_ea962d5e_e01a_11e7_8692_64006a8d5c4brow3_col1"
#                  class="data row3 col1" >
#                     Trajectory
#
#
#
#                 <td id="T_ea962d5e_e01a_11e7_8692_64006a8d5c4brow3_col2"
#                  class="data row3 col2" >
#                     {u'type': {u'type': u'AUV', u'name': u'Glider'}, u'id': 568, u'name': u'SCB-SLDEEP004'}
#
#
#
#                 <td id="T_ea962d5e_e01a_11e7_8692_64006a8d5c4brow3_col3"
#                  class="data row3 col3" >
#                     {u'type': {u'type': u'AUV', u'name': u'Glider'}, u'id': 290, u'name': u'sdeep04'}
#
#
#
#                 <td id="T_ea962d5e_e01a_11e7_8692_64006a8d5c4brow3_col4"
#                  class="data row3 col4" >
#                     2017-07-28T17:48:23Z
#
#
#
#                 <td id="T_ea962d5e_e01a_11e7_8692_64006a8d5c4brow3_col5"
#                  class="data row3 col5" >
#                     2017-08-19T10:43:42Z
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_ea962d5e_e01a_11e7_8692_64006a8d5c4b"
#                  class="row_heading

# %% [markdown]
# From above table is way easier to see that there are actually 3 deployments sources (platfrom&instruments ensemble): <br>
# a) instrument SCB-SLDEEP001 on board on platform sdeep01<br>
# b) instrument SCB-SLDEEP004 on board on platform sdeep04<br>
# c) instrument SCB-SLDEEP005 on board on platform sdeep05

# %% [markdown]
# But these combos have beeen realeased more than once (examples a and b) and from every one of them it has been obtained more than one data type (Real Time, Delayed Time and Trayectory data).

# %%
ensemble = []
for element in array:
    ensemble.append(element[2]['name']+'-'+element[3]['name']+'('+element[4].split('T')[0]+'/'+element[5].split('T')[0]+')')
Counter(ensemble)
# Out:
# Counter({u'SCB-SLDEEP001-sdeep01(2016-12-30/2017-02-10)': 1,
#          u'SCB-SLDEEP001-sdeep01(2016-12-30/2017-02-15)': 2,
#          u'SCB-SLDEEP001-sdeep01(2017-05-10/2017-07-04)': 1,
#          u'SCB-SLDEEP001-sdeep01(2017-05-10/2017-07-06)': 2,
#          u'SCB-SLDEEP004-sdeep04(2017-07-28/2017-08-19)': 3,
#          u'SCB-SLDEEP004-sdeep04(2017-09-13/2017-10-24)': 2,
#          u'SCB-SLDEEP005-sdeep05(2017-03-03/2017-04-25)': 3})

# %% [markdown]
# Where instrument SCB-SLDEEP001 on board on platform sdeep01 has been released twice:
#     - From 2016-12-30 to 2017-02-10/15 (3 types of data)
#     - From 2017-05-10 to 2017-07-04/06 (3 types of data)
# Where instrument SCB-SLDEEP004 on board on platform sdeep04 has been released twice:
#     - From 2017-07-28 to 2017-08-19 (3 types of data)
#     - From 2017-09-13 to 2017-10-24 (just 2 types of data)
# Where instrument SCB-SLDEEP005 on board on platform sdeep05 has been released once:
#     - From 2017-03-03 to 2017-04-25 (3 types of data)

# %% [markdown]
# Later, with the id of the different ata sources (DATA-SOURCES/ID/DATA) or just exploring its 'entries' (netCDFs) yoiu can work with its data. See how at:<ul><li><a href="https://github.com/pazrg/SOCIB_API/blob/master/data_sources/straightforward_data_access_for_data_sources.ipynb" target="_blank">API & DATA-SOURCE/ID/DATA ENPOINT</a></li><li><a href="https://github.com/pazrg/SOCIB_API/blob/master/data_sources/working_with_data_sources_netcdfs.ipynb" target="_blank">API & THREDDS netCDFs</a></li></ul>

# %% [markdown]
# <h3> DATA-PRODUCTS PARAMS</h3>

# %% [markdown]
# SOCIB API enables users to setup certain conditions to match for DATA-PRODUCT filtering so that, from the generic answer, it is possible  to keep only the ones that better suits user needs. These conditions can be built via the so-called PARAMS. PARAMS are additional url elements that allows to filter the initial/bare ENDPOINT answer. These params can be added after a given generic/bare ENDPOINT alone or in combination (more than one):

# %% [markdown]
# There are a total of 11 PARAMS you can play with in order to filter the /DATA-PRODUCTS/ ENDPOINT initial answer. All of them can be found next:
# <ul><li>initial_datetime</li>
#     <ul>UTC time as YYY-MM-DDTHH:MM:SS</ul>
# </ul>
# <ul><li>end_datetime</li>
#     <ul>UTC time as YYY-MM-DDTHH:MM:SS</ul>
# </ul>
# <ul><li>standard_variable</li>
#     <ul>Any value of those returned by <a href="https://github.com/pazrg/SOCIB_API/blob/master/tips/quick_start.ipynb" target="_blank">/standard-variables/ ENDPOINT</a></ul>
# </ul>
# <ul><li>bbox</li>
#     <ul>Area where a given deployment has been operating since deployed (released or placed). Area should be specify as a 4 comma-separated float numbers following the structure: min. lat., max. lat., min. lon., max. lon</ul>
# </ul>
# <ul><li>platform_type</li>
#     <ul>Any value of those returned by <a href="https://github.com/pazrg/SOCIB_API/blob/master/tips/quick_start.ipynb" target="_blank">/platform-types/ ENDPOINT</a></ul>
# </ul>
# <ul><li>instrument_type</li>
#     <ul>Any value of those returned by <a href="https://github.com/pazrg/SOCIB_API/blob/master/tips/quick_start.ipynb" target="_blank">/instrument-types/ ENDPOINT</a></ul>
# </ul>
# <ul><li>data_type</li>
#     <ul>Any value of those returned by <a href="https://github.com/pazrg/SOCIB_API/blob/master/tips/quick_start.ipynb" target="_blank">/data-types/ ENDPOINT</a></ul>
# </ul>
# <ul><li>status</li>
#     <ul>Two posibilities: active or completed</ul>
# </ul>
# <ul><li>name</li>
#     <ul>Filters the products which contains the given text in its name or description (Case insensitive)</ul>
# </ul>
# <ul><li>detail</li>
#     <ul>"full" or "summary"</ul>
# </ul>
# <ul><li>page</li>
#     <ul>A pagination of 8 is currently set-up when retrieveing the list of data-sources. When <i>count</i> is more than 8 you should loop over the different pages (1 as default) in order to access all deployments details. </ul>
# </ul>

# %% [markdown]
# Let's find all glider missions (undertanding such as those where at least a glider was deployed) that happened in an specific time window:

# %%
#several PARAM examples
end_point = '/data-products/'
PARAMS = ['platform_type', 'initial_datetime','end_datetime']
PARAMS_values = ['Glider','2016-02-01T00:00:00','2017-03-01T00:00:00']

#concatenation of PARAMS
param_concatenation = params_concatenation(PARAMS,PARAMS_values)

#request with more than one PARAM
request_surf = requests.get('%s%s?%s' % (api_url, end_point,param_concatenation), headers=headers)
response_surf = json.loads(request_surf.text)

print('Requested url: '+('%s%s?%s' % (api_url, end_point,param_concatenation)).replace (" ","%20"))
print(' ')
print('SOCIB offers %s products involving:' %(response_surf['count']))
for param, value in zip(PARAMS,PARAMS_values):
    print('   '+value +' as '+ param)
# Out:
# Requested url: http://api.socib.es/data-products/?platform_type=Glider&initial_datetime=2016-02-01T00:00:00&end_datetime=2017-03-01T00:00:00
#
# SOCIB offers 6 products involving:
#    Glider as platform_type
#    2016-02-01T00:00:00 as initial_datetime
#    2017-03-01T00:00:00 as end_datetime

# %%
#getting the a quick view of the above products
a = '%s%s?%s' % (api_url, end_point,param_concatenation) 
ids = []
values = []
while a != None:
    #requesting every data product to check its summary properties
    request_prof = requests.get(a, headers=headers)
    response_prof = json.loads(request_prof.text)
    numb = 1
    for product in response_prof['results']:
        values.append(product.values())
        ids.append(product['id'])
    a = response_prof['next']
df = pd.DataFrame(values, index=ids, columns=product.keys())
display(df.style)
# Out:
#         <style  type="text/css" >
#
#
#         </style>
#
#         <table id="T_2ffc3f54_e02b_11e7_8692_64006a8d5c4b" None>
#
#
#         <thead>
#
#             <tr>
#
#
#                 <th class="blank level0" >
#
#
#
#
#                 <th class="col_heading level0 col0" colspan=1>
#                   description
#
#
#
#                 <th class="col_heading level0 col1" colspan=1>
#                   id
#
#
#
#                 <th class="col_heading level0 col2" colspan=1>
#                   name
#
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#
#                 <th id="T_2ffc3f54_e02b_11e7_8692_64006a8d5c4b"
#                  class="row_heading level0 row0" rowspan=1>
#                     garicast-2017
#
#
#
#                 <td id="T_2ffc3f54_e02b_11e7_8692_64006a8d5c4brow0_col0"
#                  class="data row0 col0" >
#                     GARICAST stands for Glider Against Rosette Inter-comparison CAST. This is the name given, at SOCIB, to the action of attaching an AUV-GLIDER to SOCIB-RV's CTD-Rosette and deploying this whole setup in order to gather CTD, OXY and FLNTU synoptic data from both observing platforms. The main goal of this effort is to validate Glider sensors taking Rosette sensors as benchmark. Consequently, GARICAST missions always occur in the frame of a SOCIB-RV cruise.
#
# GARICAST_#### stands for the annual (year ####) campaign of Glider sensor validation by means of using SOCIB-RV as calibration facility.
#
#
#
#                 <td id="T_2ffc3f54_e02b_11e7_8692_64006a8d5c4brow0_col1"
#                  class="data row0 col1" >
#                     garicast-2017
#
#
#
#                 <td id="T_2ffc3f54_e02b_11e7_8692_64006a8d5c4brow0_col2"
#                  class="data row0 col2" >
#                     GARICAST 2017
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_2ffc3f54_e02b_11e7_8692_64006a8d5c4b"
#                  class="row_heading level0 row1" rowspan=1>
#                     glider-canales2016
#
#
#
#                 <td id="T_2ffc3f54_e02b_11e7_8692_64006a8d5c4brow1_col0"
#                  class="data row1 col0" >
#                     Canales cruise, defined and followed by SOCIB (with in kind collaboration of IMEDEA-CSIC) to implement the inter-annual monitoring endurance line (ENL1) covering the Balearic channels of Mallorca and EĂŻvissa during the year 2016 as defined in the SOCIB's Implementation Plan 2013. The list of waypoints conforming this cruise stand as the default set for all the canales missions for the campaign of 2016; nevertheless, slightly modifications may be applied under special circumstances.
#
#
#
#                 <td id="T_2ffc3f54_e02b_11e7_8692_64006a8d5c4brow1_col1"
#                  class="data row1 col1" >
#                     glider-canales2016
#
#
#
#                 <td id="T_2ffc3f54_e02b_11e7_8692_64006a8d5c4brow1_col2"
#                  class="data row1 col2" >
#                     glider canales2016
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_2ffc3f54_e02b_11e7_8692_64006a8d5c4b"
#                  class="row_heading level0 row2" rowspan=1>
#                     glider-canales2017
#
#
#
#                 <td id="T_2ffc3f54_e02b_11e7_8692_64006a8d5c4brow2_col0"
#                  class="data row2 col0" >
#                     Canales cruise, defined and followed by SOCIB (with in kind collaboration of IMEDEA-CSIC) to implement the inter-annual monitoring endurance line (ENL1) covering the Balearic channels of Mallorca and EĂŻvissa during the year 2017. The list of waypoints conforming this cruise stand as the default set for all the canales missions for the campaign of 2017; nevertheless, slightly modifications may be applied under special circumstances.
#
#
#
#                 <td id="T_2ffc3f54_e02b_11e7_8692_64006a8d5c4brow2_col1"
#                  class="data row2 col1" >
#                     glider-canales2017
#
#
#
#                 <td id="T_2ffc3f54_e02b_11e7_8692_64006a8d5c4brow2_col2"
#                  class="data row2 col2" >
#                     glider canales2017
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_2ffc3f54_e02b_11e7_8692_64006a8d5c4b"
#                  class="row_heading level0 row3" rowspan=1>
#                     socib-enl-algbasin-2016
#
#
#
#                 <td id="T_2ffc3f54_e02b_11e7_8692_64006a8d5c4brow3_col0"
#                  class="data row3 col0" >
#                     (Proto)Endurance Line 2016 (demo)Campaign in the Algerian Basin (South of Mallorca)
#
#
#
#                 <td id="T_2ffc3f54_e02b_11e7_8692_64006a8d5c4brow3_col1"
#                  class="data row3 col1" >
#                     socib-enl-algbasin-2016
#
#
#
#                 <td id="T_2ffc3f54_e02b_11e7_8692_64006a8d5c4brow3_col2"
#                  class="data row3 col2" >
#                     SOCIB ENL ALGBASIN 2016
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_2ffc3f54_e02b_11e7_8692_64006a8d5c4b"
#                  class="row_heading level0 row4" rowspan=1>
#                     socib-epr-jerico-next-tna-2016
#
#
#
#                 <td id="T_2ffc3f54_e02b_11e7_8692_64006a8d5c4brow4_col0"
#                  class="data row4 col0" >
#                     SOCIB missions executed in the frame of the EU-FP7 project JERICO-NEXT (TNA program).
# Year 2016
#
#
#
#                 <td id="T_2ffc3f54_e02b_11e7_8692_64006a8d5c4brow4_col1"
#                  class="data row4 col1" >
#                     socib-epr-jerico-next-tna-2016
#
#
#
#                 <td id="T_2ffc3f54_e02b_11e7_8692_64006a8d5c4brow4_col2"
#                  class="data row4 col2" >
#                     SOCIB EPR JERICO NEXT TNA 2016
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_2ffc3f54_e02b_11e7_8692_64006a8d5c4b"
#                  class="row_heading level0 row5" rowspan=1>
#                     socib-int-glidingturtles-jul2016
#
#
#
#                 <td id="T_2ffc3f54_e02b_11e7_8692_64006a8d5c4brow5_col0"
#                  class="data row5 col0" >
#                     Multi-platform experiment that associates a sea turtle, drifters (3) and a glider.
#
#
#
#                 <td id="T_2ffc3f54_e02b_11e7_8692_64006a8d5c4brow5_col1"
#                  class="data row5 col1" >
#                     socib-int-glidingturtles-jul2016
#
#
#
#                 <td id="T_2ffc3f54_e02b_11e7_8692_64006a8d5c4brow5_col2"
#                  class="data row5 col2" >
#                     SOCIB INT GlidingTurtles Jul2016
#
#
#             </tr>
#
#         </tbody>
#         </table>

# %% [markdown]
# Let's again have a more detailed look:

# %%
props = ['description','data_type','instrument','platform','initial_datetime','end_datetime']
for product in response_prof['results']:
    detailed_end_point = '/data-products/'+product['id'] 
    detailed_request = requests.get('%s%s' % (api_url, detailed_end_point), headers=headers)
    detailed_response = json.loads(detailed_request.text)
    array = []
    ids = []
    for val in detailed_response.values():
        if type(val) is list:
            for deployment in val:
                values = []
                for key in deployment.keys():
                    if key in props:
                        values.append(deployment[key])
                array.append(values)
                ids.append(deployment['id'])
    print('* Data-sources composing product with id %s'%(product['id']))
    df = pd.DataFrame(array, index=ids, columns=props)
    display(df.style)
# Out:
# * Data-sources composing product with id garicast-2017
#         <style  type="text/css" >
#
#
#         </style>
#
#         <table id="T_db3083a8_e02b_11e7_8692_64006a8d5c4b" None>
#
#
#         <thead>
#
#             <tr>
#
#
#                 <th class="blank level0" >
#
#
#
#
#                 <th class="col_heading level0 col0" colspan=1>
#                   description
#
#
#
#                 <th class="col_heading level0 col1" colspan=1>
#                   data_type
#
#
#
#                 <th class="col_heading level0 col2" colspan=1>
#                   instrument
#
#
#
#                 <th class="col_heading level0 col3" colspan=1>
#                   platform
#
#
#
#                 <th class="col_heading level0 col4" colspan=1>
#                   initial_datetime
#
#
#
#                 <th class="col_heading level0 col5" colspan=1>
#                   end_datetime
#
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#
#                 <th id="T_db3083a8_e02b_11e7_8692_64006a8d5c4b"
#                  class="row_heading level0 row0" rowspan=1>
#                     adaba5d1dc
#
#
#
#                 <td id="T_db3083a8_e02b_11e7_8692_64006a8d5c4brow0_col0"
#                  class="data row0 col0" >
#                     Glider delayed time observational data
#
#
#
#                 <td id="T_db3083a8_e02b_11e7_8692_64006a8d5c4brow0_col1"
#                  class="data row0 col1" >
#                     Trajectory
#
#
#
#                 <td id="T_db3083a8_e02b_11e7_8692_64006a8d5c4brow0_col2"
#                  class="data row0 col2" >
#                     {u'type': {u'type': u'AUV', u'name': u'Glider'}, u'id': 197, u'name': u'SCB-SLDEEP001'}
#
#
#
#                 <td id="T_db3083a8_e02b_11e7_8692_64006a8d5c4brow0_col3"
#                  class="data row0 col3" >
#                     {u'type': {u'type': u'AUV', u'name': u'Glider'}, u'id': 108, u'name': u'sdeep01'}
#
#
#
#                 <td id="T_db3083a8_e02b_11e7_8692_64006a8d5c4brow0_col4"
#                  class="data row0 col4" >
#                     2017-02-16T10:56:36Z
#
#
#
#                 <td id="T_db3083a8_e02b_11e7_8692_64006a8d5c4brow0_col5"
#                  class="data row0 col5" >
#                     2017-02-16T17:48:36Z
#
#
#             </tr>
#
#         </tbody>
#         </table>
# * Data-sources composing product with id glider-canales2016
#         <style  type="text/css" >
#
#
#         </style>
#
#         <table id="T_dc537ccc_e02b_11e7_8692_64006a8d5c4b" None>
#
#
#         <thead>
#
#             <tr>
#
#
#                 <th class="blank level0" >
#
#
#
#
#                 <th class="col_heading level0 col0" colspan=1>
#                   description
#
#
#
#                 <th class="col_heading level0 col1" colspan=1>
#                   data_type
#
#
#
#                 <th class="col_heading level0 col2" colspan=1>
#                   instrument
#
#
#
#                 <th class="col_heading level0 col3" colspan=1>
#                   platform
#
#
#
#                 <th class="col_heading level0 col4" colspan=1>
#                   initial_datetime
#
#
#
#                 <th class="col_heading level0 col5" colspan=1>
#                   end_datetime
#
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#
#                 <th id="T_dc537ccc_e02b_11e7_8692_64006a8d5c4b"
#                  class="row_heading level0 row0" rowspan=1>
#                     d38d740b07
#
#
#
#                 <td id="T_dc537ccc_e02b_11e7_8692_64006a8d5c4brow0_col0"
#                  class="data row0 col0" >
#                     Glider delayed time observational data
#
#
#
#                 <td id="T_dc537ccc_e02b_11e7_8692_64006a8d5c4brow0_col1"
#                  class="data row0 col1" >
#                     Trajectory
#
#
#
#                 <td id="T_dc537ccc_e02b_11e7_8692_64006a8d5c4brow0_col2"
#                  class="data row0 col2" >
#                     {u'type': {u'type': u'AUV', u'name': u'Glider'}, u'id': 48, u'name': u'IME-SLDEEP002'}
#
#
#
#                 <td id="T_dc537ccc_e02b_11e7_8692_64006a8d5c4brow0_col3"
#                  class="data row0 col3" >
#                     {u'type': {u'type': u'AUV', u'name': u'Glider'}, u'id': 89, u'name': u'ideep02'}
#
#
#
#                 <td id="T_dc537ccc_e02b_11e7_8692_64006a8d5c4brow0_col4"
#                  class="data row0 col4" >
#                     2016-10-28T09:03:09Z
#
#
#
#                 <td id="T_dc537ccc_e02b_11e7_8692_64006a8d5c4brow0_col5"
#                  class="data row0 col5" >
#                     2016-12-15T14:59:55Z
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_dc537ccc_e02b_11e7_8692_64006a8d5c4b"
#                  class="row_heading level0 row1" rowspan=1>
#                     1f252b3fe0
#
#
#
#                 <td id="T_dc537ccc_e02b_11e7_8692_64006a8d5c4brow1_col0"
#                  class="data row1 col0" >
#                     Glider tracking observational data
#
#
#
#                 <td id="T_dc537ccc_e02b_11e7_8692_64006a8d5c4brow1_col1"
#                  class="data row1 col1" >
#                     Trajectory
#
#
#
#                 <td id="T_dc537ccc_e02b_11e7_8692_64006a8d5c4brow1_col2"
#                  class="data row1 col2" >
#                     {u'type': {u'type': u'AUV', u'name': u'Glider'}, u'id': 48, u'name': u'IME-SLDEEP002'}
#
#
#
#                 <td id="T_dc537ccc_e02b_11e7_8692_64006a8d5c4brow1_col3"
#                  class="data row1 col3" >
#                     {u'type': {u'type': u'AUV', u'name': u'Glider'}, u'id': 89, u'name': u'ideep02'}
#
#
#
#                 <td id="T_dc537ccc_e02b_11e7_8692_64006a8d5c4brow1_col4"
#                  class="data row1 col4" >
#                     2016-10-28T09:02:59Z
#
#
#
#                 <td id="T_dc537ccc_e02b_11e7_8692_64006a8d5c4brow1_col5"
#                  class="data row1 col5" >
#                     2016-12-15T13:57:54Z
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_dc537ccc_e02b_11e7_8692_64006a8d5c4b"
#                  class="row_heading level0 row2" rowspan=1>
#                     454c17a232
#
#
#
#                 <td id="T_dc537ccc_e02b_11e7_8692_64006a8d5c4brow2_col0"
#                  class="data row2 col0" >
#                     Glider real time observational data
#
#
#
#                 <td id="T_dc537ccc_e02b_11e7_8692_64006a8d5c4brow2_col1"
#                  class="data row2 col1" >
#                     Trajectory
#
#
#
#                 <td id="T_dc537ccc_e02b_11e7_8692_64006a8d5c4brow2_col2"
#                  class="data row2 col2" >
#                     {u'type': {u'type': u'AUV', u'name': u'Glider'}, u'id': 48, u'name': u'IME-SLDEEP002'}
#
#
#
#                 <td id="T_dc537ccc_e02b_11e7_8692_64006a8d5c4brow2_col3"
#                  class="data row2 col3" >
#                     {u'type': {u'type': u'AUV', u'name': u'Glider'}, u'id': 89, u'name': u'ideep02'}
#
#
#
#                 <td id="T_dc537ccc_e02b_11e7_8692_64006a8d5c4brow2_col4"
#                  class="data row2 col4" >
#                     2016-10-28T09:39:24Z
#
#
#
#                 <td id="T_dc537ccc_e02b_11e7_8692_64006a8d5c4brow2_col5"
#                  class="data row2 col5" >
#                     2016-12-14T20:17:23Z
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_dc537ccc_e02b_11e7_8692_64006a8d5c4b"
#                  class="row_heading level0 row3" rowspan=1>
#                     2aa2fc0f9b
#
#
#
#                 <td id="T_dc537ccc_e02b_11e7_8692_64006a8d5c4brow3_col0"
#                  class="data row3 col0" >
#                     Glider real time observational data
#
#
#
#                 <td id="T_dc537ccc_e02b_11e7_8692_64006a8d5c4brow3_col1"
#                  class="data row3 col1" >
#                     Trajectory
#
#
#
#                 <td id="T_dc537ccc_e02b_11e7_8692_64006a8d5c4brow3_col2"
#                  class="data row3 col2" >
#                     {u'type': {u'type': u'AUV', u'name': u'Glider'}, u'id': 568, u'name': u'SCB-SLDEEP004'}
#
#
#
#                 <td id="T_dc537ccc_e02b_11e7_8692_64006a8d5c4brow3_col3"
#                  class="data row3 col3" >
#                     {u'type': {u'type': u'AUV', u'name': u'Glider'}, u'id': 290, u'name': u'sdeep04'}
#
#
#
#                 <td id="T_dc537ccc_e02b_11e7_8692_64006a8d5c4brow3_col4"
#                  class="data row3 col4" >
#                     2016-09-06T10:43:13Z
#
#
#
#                 <td id="T_dc537ccc_e02b_11e7_8692_64006a8d5c4brow3_col5"
#                  class="data row3 col5" >
#                     2016-10-26T07:57:15Z
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_dc537ccc_e02b_11e7_8692_64006a8d5c4b"
#                  class="row_heading level0
# * Data-sources composing product with id glider-canales2017
#         <style  type="text/css" >
#
#
#         </style>
#
#         <table id="T_dc537ccd_e02b_11e7_8692_64006a8d5c4b" None>
#
#
#         <thead>
#
#             <tr>
#
#
#                 <th class="blank level0" >
#
#
#
#
#                 <th class="col_heading level0 col0" colspan=1>
#                   description
#
#
#
#                 <th class="col_heading level0 col1" colspan=1>
#                   data_type
#
#
#
#                 <th class="col_heading level0 col2" colspan=1>
#                   instrument
#
#
#
#                 <th class="col_heading level0 col3" colspan=1>
#                   platform
#
#
#
#                 <th class="col_heading level0 col4" colspan=1>
#                   initial_datetime
#
#
#
#                 <th class="col_heading level0 col5" colspan=1>
#                   end_datetime
#
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#
#                 <th id="T_dc537ccd_e02b_11e7_8692_64006a8d5c4b"
#                  class="row_heading level0 row0" rowspan=1>
#                     c5260f9b8a
#
#
#
#                 <td id="T_dc537ccd_e02b_11e7_8692_64006a8d5c4brow0_col0"
#                  class="data row0 col0" >
#                     Glider real time observational data
#
#
#
#                 <td id="T_dc537ccd_e02b_11e7_8692_64006a8d5c4brow0_col1"
#                  class="data row0 col1" >
#                     Trajectory
#
#
#
#                 <td id="T_dc537ccd_e02b_11e7_8692_64006a8d5c4brow0_col2"
#                  class="data row0 col2" >
#                     {u'type': {u'type': u'AUV', u'name': u'Glider'}, u'id': 568, u'name': u'SCB-SLDEEP004'}
#
#
#
#                 <td id="T_dc537ccd_e02b_11e7_8692_64006a8d5c4brow0_col3"
#                  class="data row0 col3" >
#                     {u'type': {u'type': u'AUV', u'name': u'Glider'}, u'id': 290, u'name': u'sdeep04'}
#
#
#
#                 <td id="T_dc537ccd_e02b_11e7_8692_64006a8d5c4brow0_col4"
#                  class="data row0 col4" >
#                     2017-09-13T10:35:56Z
#
#
#
#                 <td id="T_dc537ccd_e02b_11e7_8692_64006a8d5c4brow0_col5"
#                  class="data row0 col5" >
#                     2017-10-24T03:45:33Z
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_dc537ccd_e02b_11e7_8692_64006a8d5c4b"
#                  class="row_heading level0 row1" rowspan=1>
#                     4dd1476b27
#
#
#
#                 <td id="T_dc537ccd_e02b_11e7_8692_64006a8d5c4brow1_col0"
#                  class="data row1 col0" >
#                     Glider tracking observational data
#
#
#
#                 <td id="T_dc537ccd_e02b_11e7_8692_64006a8d5c4brow1_col1"
#                  class="data row1 col1" >
#                     Trajectory
#
#
#
#                 <td id="T_dc537ccd_e02b_11e7_8692_64006a8d5c4brow1_col2"
#                  class="data row1 col2" >
#                     {u'type': {u'type': u'AUV', u'name': u'Glider'}, u'id': 568, u'name': u'SCB-SLDEEP004'}
#
#
#
#                 <td id="T_dc537ccd_e02b_11e7_8692_64006a8d5c4brow1_col3"
#                  class="data row1 col3" >
#                     {u'type': {u'type': u'AUV', u'name': u'Glider'}, u'id': 290, u'name': u'sdeep04'}
#
#
#
#                 <td id="T_dc537ccd_e02b_11e7_8692_64006a8d5c4brow1_col4"
#                  class="data row1 col4" >
#                     2017-09-13T10:02:26Z
#
#
#
#                 <td id="T_dc537ccd_e02b_11e7_8692_64006a8d5c4brow1_col5"
#                  class="data row1 col5" >
#                     2017-10-24T04:02:16Z
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_dc537ccd_e02b_11e7_8692_64006a8d5c4b"
#                  class="row_heading level0 row2" rowspan=1>
#                     a95b4e2fc0
#
#
#
#                 <td id="T_dc537ccd_e02b_11e7_8692_64006a8d5c4brow2_col0"
#                  class="data row2 col0" >
#                     Glider real time observational data
#
#
#
#                 <td id="T_dc537ccd_e02b_11e7_8692_64006a8d5c4brow2_col1"
#                  class="data row2 col1" >
#                     Trajectory
#
#
#
#                 <td id="T_dc537ccd_e02b_11e7_8692_64006a8d5c4brow2_col2"
#                  class="data row2 col2" >
#                     {u'type': {u'type': u'AUV', u'name': u'Glider'}, u'id': 568, u'name': u'SCB-SLDEEP004'}
#
#
#
#                 <td id="T_dc537ccd_e02b_11e7_8692_64006a8d5c4brow2_col3"
#                  class="data row2 col3" >
#                     {u'type': {u'type': u'AUV', u'name': u'Glider'}, u'id': 290, u'name': u'sdeep04'}
#
#
#
#                 <td id="T_dc537ccd_e02b_11e7_8692_64006a8d5c4brow2_col4"
#                  class="data row2 col4" >
#                     2017-07-28T17:49:21Z
#
#
#
#                 <td id="T_dc537ccd_e02b_11e7_8692_64006a8d5c4brow2_col5"
#                  class="data row2 col5" >
#                     2017-08-19T05:47:49Z
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_dc537ccd_e02b_11e7_8692_64006a8d5c4b"
#                  class="row_heading level0 row3" rowspan=1>
#                     0fe811ec23
#
#
#
#                 <td id="T_dc537ccd_e02b_11e7_8692_64006a8d5c4brow3_col0"
#                  class="data row3 col0" >
#                     Glider delayed time observational data
#
#
#
#                 <td id="T_dc537ccd_e02b_11e7_8692_64006a8d5c4brow3_col1"
#                  class="data row3 col1" >
#                     Trajectory
#
#
#
#                 <td id="T_dc537ccd_e02b_11e7_8692_64006a8d5c4brow3_col2"
#                  class="data row3 col2" >
#                     {u'type': {u'type': u'AUV', u'name': u'Glider'}, u'id': 568, u'name': u'SCB-SLDEEP004'}
#
#
#
#                 <td id="T_dc537ccd_e02b_11e7_8692_64006a8d5c4brow3_col3"
#                  class="data row3 col3" >
#                     {u'type': {u'type': u'AUV', u'name': u'Glider'}, u'id': 290, u'name': u'sdeep04'}
#
#
#
#                 <td id="T_dc537ccd_e02b_11e7_8692_64006a8d5c4brow3_col4"
#                  class="data row3 col4" >
#                     2017-07-28T17:48:23Z
#
#
#
#                 <td id="T_dc537ccd_e02b_11e7_8692_64006a8d5c4brow3_col5"
#                  class="data row3 col5" >
#                     2017-08-19T10:43:42Z
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_dc537ccd_e02b_11e7_8692_64006a8d5c4b"
#                  class="row_heading
# * Data-sources composing product with id socib-enl-algbasin-2016
#         <style  type="text/css" >
#
#
#         </style>
#
#         <table id="T_dc537cce_e02b_11e7_8692_64006a8d5c4b" None>
#
#
#         <thead>
#
#             <tr>
#
#
#                 <th class="blank level0" >
#
#
#
#
#                 <th class="col_heading level0 col0" colspan=1>
#                   description
#
#
#
#                 <th class="col_heading level0 col1" colspan=1>
#                   data_type
#
#
#
#                 <th class="col_heading level0 col2" colspan=1>
#                   instrument
#
#
#
#                 <th class="col_heading level0 col3" colspan=1>
#                   platform
#
#
#
#                 <th class="col_heading level0 col4" colspan=1>
#                   initial_datetime
#
#
#
#                 <th class="col_heading level0 col5" colspan=1>
#                   end_datetime
#
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#
#                 <th id="T_dc537cce_e02b_11e7_8692_64006a8d5c4b"
#                  class="row_heading level0 row0" rowspan=1>
#                     d48cf2460d
#
#
#
#                 <td id="T_dc537cce_e02b_11e7_8692_64006a8d5c4brow0_col0"
#                  class="data row0 col0" >
#                     Glider real time observational data
#
#
#
#                 <td id="T_dc537cce_e02b_11e7_8692_64006a8d5c4brow0_col1"
#                  class="data row0 col1" >
#                     Trajectory
#
#
#
#                 <td id="T_dc537cce_e02b_11e7_8692_64006a8d5c4brow0_col2"
#                  class="data row0 col2" >
#                     {u'type': {u'type': u'AUV', u'name': u'Glider'}, u'id': 195, u'name': u'IME-SLDEEP000'}
#
#
#
#                 <td id="T_dc537cce_e02b_11e7_8692_64006a8d5c4brow0_col3"
#                  class="data row0 col3" >
#                     {u'type': {u'type': u'AUV', u'name': u'Glider'}, u'id': 105, u'name': u'ideep00'}
#
#
#
#                 <td id="T_dc537cce_e02b_11e7_8692_64006a8d5c4brow0_col4"
#                  class="data row0 col4" >
#                     2016-05-25T11:26:36Z
#
#
#
#                 <td id="T_dc537cce_e02b_11e7_8692_64006a8d5c4brow0_col5"
#                  class="data row0 col5" >
#                     2016-06-02T08:58:33Z
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_dc537cce_e02b_11e7_8692_64006a8d5c4b"
#                  class="row_heading level0 row1" rowspan=1>
#                     7578a3aba3
#
#
#
#                 <td id="T_dc537cce_e02b_11e7_8692_64006a8d5c4brow1_col0"
#                  class="data row1 col0" >
#                     Glider delayed time observational data
#
#
#
#                 <td id="T_dc537cce_e02b_11e7_8692_64006a8d5c4brow1_col1"
#                  class="data row1 col1" >
#                     Trajectory
#
#
#
#                 <td id="T_dc537cce_e02b_11e7_8692_64006a8d5c4brow1_col2"
#                  class="data row1 col2" >
#                     {u'type': {u'type': u'AUV', u'name': u'Glider'}, u'id': 195, u'name': u'IME-SLDEEP000'}
#
#
#
#                 <td id="T_dc537cce_e02b_11e7_8692_64006a8d5c4brow1_col3"
#                  class="data row1 col3" >
#                     {u'type': {u'type': u'AUV', u'name': u'Glider'}, u'id': 105, u'name': u'ideep00'}
#
#
#
#                 <td id="T_dc537cce_e02b_11e7_8692_64006a8d5c4brow1_col4"
#                  class="data row1 col4" >
#                     2016-05-25T11:26:13Z
#
#
#
#                 <td id="T_dc537cce_e02b_11e7_8692_64006a8d5c4brow1_col5"
#                  class="data row1 col5" >
#                     2016-06-17T09:54:59Z
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_dc537cce_e02b_11e7_8692_64006a8d5c4b"
#                  class="row_heading level0 row2" rowspan=1>
#                     c0cc4a9db1
#
#
#
#                 <td id="T_dc537cce_e02b_11e7_8692_64006a8d5c4brow2_col0"
#                  class="data row2 col0" >
#                     Glider tracking observational data
#
#
#
#                 <td id="T_dc537cce_e02b_11e7_8692_64006a8d5c4brow2_col1"
#                  class="data row2 col1" >
#                     Trajectory
#
#
#
#                 <td id="T_dc537cce_e02b_11e7_8692_64006a8d5c4brow2_col2"
#                  class="data row2 col2" >
#                     {u'type': {u'type': u'AUV', u'name': u'Glider'}, u'id': 195, u'name': u'IME-SLDEEP000'}
#
#
#
#                 <td id="T_dc537cce_e02b_11e7_8692_64006a8d5c4brow2_col3"
#                  class="data row2 col3" >
#                     {u'type': {u'type': u'AUV', u'name': u'Glider'}, u'id': 105, u'name': u'ideep00'}
#
#
#
#                 <td id="T_dc537cce_e02b_11e7_8692_64006a8d5c4brow2_col4"
#                  class="data row2 col4" >
#                     2016-05-25T10:04:27Z
#
#
#
#                 <td id="T_dc537cce_e02b_11e7_8692_64006a8d5c4brow2_col5"
#                  class="data row2 col5" >
#                     2016-06-02T10:06:35Z
#
#
#             </tr>
#
#         </tbody>
#         </table>
# * Data-sources composing product with id socib-epr-jerico-next-tna-2016
#         <style  type="text/css" >
#
#
#         </style>
#
#         <table id="T_dc537ccf_e02b_11e7_8692_64006a8d5c4b" None>
#
#
#         <thead>
#
#             <tr>
#
#
#                 <th class="blank level0" >
#
#
#
#
#                 <th class="col_heading level0 col0" colspan=1>
#                   description
#
#
#
#                 <th class="col_heading level0 col1" colspan=1>
#                   data_type
#
#
#
#                 <th class="col_heading level0 col2" colspan=1>
#                   instrument
#
#
#
#                 <th class="col_heading level0 col3" colspan=1>
#                   platform
#
#
#
#                 <th class="col_heading level0 col4" colspan=1>
#                   initial_datetime
#
#
#
#                 <th class="col_heading level0 col5" colspan=1>
#                   end_datetime
#
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#
#                 <th id="T_dc537ccf_e02b_11e7_8692_64006a8d5c4b"
#                  class="row_heading level0 row0" rowspan=1>
#                     876851793e
#
#
#
#                 <td id="T_dc537ccf_e02b_11e7_8692_64006a8d5c4brow0_col0"
#                  class="data row0 col0" >
#                     Glider real time observational data
#
#
#
#                 <td id="T_dc537ccf_e02b_11e7_8692_64006a8d5c4brow0_col1"
#                  class="data row0 col1" >
#                     Trajectory
#
#
#
#                 <td id="T_dc537ccf_e02b_11e7_8692_64006a8d5c4brow0_col2"
#                  class="data row0 col2" >
#                     {u'type': {u'type': u'AUV', u'name': u'Glider'}, u'id': 197, u'name': u'SCB-SLDEEP001'}
#
#
#
#                 <td id="T_dc537ccf_e02b_11e7_8692_64006a8d5c4brow0_col3"
#                  class="data row0 col3" >
#                     {u'type': {u'type': u'AUV', u'name': u'Glider'}, u'id': 108, u'name': u'sdeep01'}
#
#
#
#                 <td id="T_dc537ccf_e02b_11e7_8692_64006a8d5c4brow0_col4"
#                  class="data row0 col4" >
#                     2016-11-04T13:17:18Z
#
#
#
#                 <td id="T_dc537ccf_e02b_11e7_8692_64006a8d5c4brow0_col5"
#                  class="data row0 col5" >
#                     2016-12-23T04:58:55Z
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_dc537ccf_e02b_11e7_8692_64006a8d5c4b"
#                  class="row_heading level0 row1" rowspan=1>
#                     54b5e67374
#
#
#
#                 <td id="T_dc537ccf_e02b_11e7_8692_64006a8d5c4brow1_col0"
#                  class="data row1 col0" >
#                     Glider delayed time observational data
#
#
#
#                 <td id="T_dc537ccf_e02b_11e7_8692_64006a8d5c4brow1_col1"
#                  class="data row1 col1" >
#                     Trajectory
#
#
#
#                 <td id="T_dc537ccf_e02b_11e7_8692_64006a8d5c4brow1_col2"
#                  class="data row1 col2" >
#                     {u'type': {u'type': u'AUV', u'name': u'Glider'}, u'id': 197, u'name': u'SCB-SLDEEP001'}
#
#
#
#                 <td id="T_dc537ccf_e02b_11e7_8692_64006a8d5c4brow1_col3"
#                  class="data row1 col3" >
#                     {u'type': {u'type': u'AUV', u'name': u'Glider'}, u'id': 108, u'name': u'sdeep01'}
#
#
#
#                 <td id="T_dc537ccf_e02b_11e7_8692_64006a8d5c4brow1_col4"
#                  class="data row1 col4" >
#                     2016-11-04T11:58:55Z
#
#
#
#                 <td id="T_dc537ccf_e02b_11e7_8692_64006a8d5c4brow1_col5"
#                  class="data row1 col5" >
#                     2016-12-23T08:48:54Z
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_dc537ccf_e02b_11e7_8692_64006a8d5c4b"
#                  class="row_heading level0 row2" rowspan=1>
#                     a64d6fa343
#
#
#
#                 <td id="T_dc537ccf_e02b_11e7_8692_64006a8d5c4brow2_col0"
#                  class="data row2 col0" >
#                     Glider tracking observational data
#
#
#
#                 <td id="T_dc537ccf_e02b_11e7_8692_64006a8d5c4brow2_col1"
#                  class="data row2 col1" >
#                     Trajectory
#
#
#
#                 <td id="T_dc537ccf_e02b_11e7_8692_64006a8d5c4brow2_col2"
#                  class="data row2 col2" >
#                     {u'type': {u'type': u'AUV', u'name': u'Glider'}, u'id': 197, u'name': u'SCB-SLDEEP001'}
#
#
#
#                 <td id="T_dc537ccf_e02b_11e7_8692_64006a8d5c4brow2_col3"
#                  class="data row2 col3" >
#                     {u'type': {u'type': u'AUV', u'name': u'Glider'}, u'id': 108, u'name': u'sdeep01'}
#
#
#
#                 <td id="T_dc537ccf_e02b_11e7_8692_64006a8d5c4brow2_col4"
#                  class="data row2 col4" >
#                     2016-11-04T11:36:54Z
#
#
#
#                 <td id="T_dc537ccf_e02b_11e7_8692_64006a8d5c4brow2_col5"
#                  class="data row2 col5" >
#                     2016-12-23T09:10:17Z
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_dc537ccf_e02b_11e7_8692_64006a8d5c4b"
#                  class="row_heading level0 row3" rowspan=1>
#                     22ae7dbe98
#
#
#
#                 <td id="T_dc537ccf_e02b_11e7_8692_64006a8d5c4brow3_col0"
#                  class="data row3 col0" >
#                     Glider tracking observational data
#
#
#
#                 <td id="T_dc537ccf_e02b_11e7_8692_64006a8d5c4brow3_col1"
#                  class="data row3 col1" >
#                     Trajectory
#
#
#
#                 <td id="T_dc537ccf_e02b_11e7_8692_64006a8d5c4brow3_col2"
#                  class="data row3 col2" >
#                     {u'type': {u'type': u'AUV', u'name': u'Glider'}, u'id': 196, u'name': u'SCB-SLDEEP000'}
#
#
#
#                 <td id="T_dc537ccf_e02b_11e7_8692_64006a8d5c4brow3_col3"
#                  class="data row3 col3" >
#                     {u'type': {u'type': u'AUV', u'name': u'Glider'}, u'id': 107, u'name': u'sdeep00'}
#
#
#
#                 <td id="T_dc537ccf_e02b_11e7_8692_64006a8d5c4brow3_col4"
#                  class="data row3 col4" >
#                     2015-10-19T10:05:33Z
#
#
#
#                 <td id="T_dc537ccf_e02b_11e7_8692_64006a8d5c4brow3_col5"
#                  class="data row3 col5" >
#                     2015-12-11T09:47:37Z
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_dc537ccf_e02b_11e7_8692_64006a8d5c4b"
#                  class="row_heading l
# * Data-sources composing product with id socib-int-glidingturtles-jul2016
#         <style  type="text/css" >
#
#
#         </style>
#
#         <table id="T_dc537cd0_e02b_11e7_8692_64006a8d5c4b" None>
#
#
#         <thead>
#
#             <tr>
#
#
#                 <th class="blank level0" >
#
#
#
#
#                 <th class="col_heading level0 col0" colspan=1>
#                   description
#
#
#
#                 <th class="col_heading level0 col1" colspan=1>
#                   data_type
#
#
#
#                 <th class="col_heading level0 col2" colspan=1>
#                   instrument
#
#
#
#                 <th class="col_heading level0 col3" colspan=1>
#                   platform
#
#
#
#                 <th class="col_heading level0 col4" colspan=1>
#                   initial_datetime
#
#
#
#                 <th class="col_heading level0 col5" colspan=1>
#                   end_datetime
#
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#
#                 <th id="T_dc537cd0_e02b_11e7_8692_64006a8d5c4b"
#                  class="row_heading level0 row0" rowspan=1>
#                     be465fae39
#
#
#
#                 <td id="T_dc537cd0_e02b_11e7_8692_64006a8d5c4brow0_col0"
#                  class="data row0 col0" >
#                     Surface drifter observational data
#
#
#
#                 <td id="T_dc537cd0_e02b_11e7_8692_64006a8d5c4brow0_col1"
#                  class="data row0 col1" >
#                     Trajectory
#
#
#
#                 <td id="T_dc537cd0_e02b_11e7_8692_64006a8d5c4brow0_col2"
#                  class="data row0 col2" >
#                     {u'type': {u'type': u'Drifter', u'name': u'Surface drifter'}, u'id': 527, u'name': u'SCB-ODi013'}
#
#
#
#                 <td id="T_dc537cd0_e02b_11e7_8692_64006a8d5c4brow0_col3"
#                  class="data row0 col3" >
#                     {u'type': {u'type': u'Drifter', u'name': u'Surface drifter'}, u'id': 298, u'name': u'Drifter_ODi024'}
#
#
#
#                 <td id="T_dc537cd0_e02b_11e7_8692_64006a8d5c4brow0_col4"
#                  class="data row0 col4" >
#                     2016-07-13T10:40:00Z
#
#
#
#                 <td id="T_dc537cd0_e02b_11e7_8692_64006a8d5c4brow0_col5"
#                  class="data row0 col5" >
#                     2016-07-17T15:32:00Z
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_dc537cd0_e02b_11e7_8692_64006a8d5c4b"
#                  class="row_heading level0 row1" rowspan=1>
#                     60806c04fe
#
#
#
#                 <td id="T_dc537cd0_e02b_11e7_8692_64006a8d5c4brow1_col0"
#                  class="data row1 col0" >
#                     Surface drifter observational data
#
#
#
#                 <td id="T_dc537cd0_e02b_11e7_8692_64006a8d5c4brow1_col1"
#                  class="data row1 col1" >
#                     Trajectory
#
#
#
#                 <td id="T_dc537cd0_e02b_11e7_8692_64006a8d5c4brow1_col2"
#                  class="data row1 col2" >
#                     {u'type': {u'type': u'Drifter', u'name': u'Surface drifter'}, u'id': 526, u'name': u'SCB-ODi012'}
#
#
#
#                 <td id="T_dc537cd0_e02b_11e7_8692_64006a8d5c4brow1_col3"
#                  class="data row1 col3" >
#                     {u'type': {u'type': u'Drifter', u'name': u'Surface drifter'}, u'id': 275, u'name': u'Drifter_ODi023'}
#
#
#
#                 <td id="T_dc537cd0_e02b_11e7_8692_64006a8d5c4brow1_col4"
#                  class="data row1 col4" >
#                     2016-07-13T10:20:00Z
#
#
#
#                 <td id="T_dc537cd0_e02b_11e7_8692_64006a8d5c4brow1_col5"
#                  class="data row1 col5" >
#                     2016-07-18T01:50:00Z
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_dc537cd0_e02b_11e7_8692_64006a8d5c4b"
#                  class="row_heading level0 row2" rowspan=1>
#                     ab9cbe89dd
#
#
#
#                 <td id="T_dc537cd0_e02b_11e7_8692_64006a8d5c4brow2_col0"
#                  class="data row2 col0" >
#                     Glider real time observational data
#
#
#
#                 <td id="T_dc537cd0_e02b_11e7_8692_64006a8d5c4brow2_col1"
#                  class="data row2 col1" >
#                     Trajectory
#
#
#
#                 <td id="T_dc537cd0_e02b_11e7_8692_64006a8d5c4brow2_col2"
#                  class="data row2 col2" >
#                     {u'type': {u'type': u'AUV', u'name': u'Glider'}, u'id': 30, u'name': u'IME-SLCOST000'}
#
#
#
#                 <td id="T_dc537cd0_e02b_11e7_8692_64006a8d5c4brow2_col3"
#                  class="data row2 col3" >
#                     {u'type': {u'type': u'AUV', u'name': u'Glider'}, u'id': 103, u'name': u'icoast00'}
#
#
#
#                 <td id="T_dc537cd0_e02b_11e7_8692_64006a8d5c4brow2_col4"
#                  class="data row2 col4" >
#                     2016-07-13T10:02:08Z
#
#
#
#                 <td id="T_dc537cd0_e02b_11e7_8692_64006a8d5c4brow2_col5"
#                  class="data row2 col5" >
#                     2016-07-13T15:48:52Z
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_dc537cd0_e02b_11e7_8692_64006a8d5c4b"
#                  class="row_heading level0 row3" rowspan=1>
#                     eba31a2d1c
#
#
#
#                 <td id="T_dc537cd0_e02b_11e7_8692_64006a8d5c4brow3_col0"
#                  class="data row3 col0" >
#                     Glider delayed time observational data
#
#
#
#                 <td id="T_dc537cd0_e02b_11e7_8692_64006a8d5c4brow3_col1"
#                  class="data row3 col1" >
#                     Trajectory
#
#
#
#                 <td id="T_dc537cd0_e02b_11e7_8692_64006a8d5c4brow3_col2"
#                  class="data row3 col2" >
#                     {u'type': {u'type': u'AUV', u'name': u'Glider'}, u'id': 30, u'name': u'IME-SLCOST000'}
#
#
#
#                 <td id="T_dc537cd0_e02b_11e7_8692_64006a8d5c4brow3_col3"
#                  class="data row3 col3" >
#                     {u'type': {u'type': u'AUV', u'name': u'Glider'}, u'id': 103, u'name': u'icoast00'}
#
#
#
#                 <td id="T_dc537cd0_e02b_11e7_8692_64006a8d5c4brow3_col4"
#                  class="data row3 col4" >
#                     2016-07-13T10:02:01Z
#
#
#
#                 <td id="T_dc537cd0_e02b_11e7_8692_64006a8d5c4brow3_col5"
#                  class="data row3 col5" >
#                     2016-07-26T08:28:49Z
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_dc537cd0_e02b_1
