# %% [markdown]
# <h1 class="header"><img class="logo" src="../images/socib_logo.png" width="200px"></h1>

# %% [markdown]
# <h3> STYLING NOTEBOOK (OPTIONAL)</h3>

# %%
from IPython.core.display import HTML
import urllib
HTML(urllib.urlopen('https://raw.githubusercontent.com/socib/API_examples/master/style/custom/custom.css').read())
# Out:
# <style>
#
# h1{
# 	float:right !important
# }
#
# h1>img{
# 	width: 200px !important
# }
#
# h3{
# 	background-color: #00334C;
# 	border: 1px solid #e3e3e3;
# 	border-radius: 4px;
# 	color: #3dabb6;
# 	padding: 19px
# }
#
# h3>span{
# 	border: 1px solid #3dabb6;
# 	border-radius: 4px;
# 	background-color: #3dabb6;
# 	color: white;
# 	padding: 5px
# }
#
# ul>li>b{
# 	border: 1px solid #3dabb6;
# 	border-radius: 4px;
# 	background-color: #3dabb6;
# 	color: white; padding: 5px;
# }
# </style>

# %% [markdown]
# <h3> HANDY PYTHON PACKAGES </h3>

# %%
import requests
import json
from IPython.display import display, HTML, JSON
import matplotlib.pyplot as plt
import numpy as np
import datetime
from json2html import *
from IPython.display import HTML, display
# %matplotlib inline

# %% [markdown]
# <h3> PREREQUISITES </h3>

# %%
api_key = '' #write you SOCIB api_key
api_url = 'http://api.socib.es'
headers = {
    'accept': 'application/vnd.socib+json',
    'apikey': api_key,
}

# %% [markdown]
# <h3> REQUESTING A DATA-SOURCE'S DATA <span>WITH PARAMS</span></h3>

# %% [markdown]
# As already seen in ['Subsetting a data-source's data'](subsetting_a_data_sources_data.ipynb), there are parameters that added to an endpoint allows applying some filtering over the generic answer: let's have a look to extra ones available for the <b>/data-sources/{id}/data</b> auxiliary endpoint and apply them to the a deployment.

# %% [markdown]
# <h3>1. FIND A DATA-SOURCE</h3>

# %% [markdown]
# Setting a certain time range, a defined area, a certain platform type and a certain variable to find a number of matching deployments:

# %%
time_range_start = '2016-04-15T15:00:00' # should match the notation YYYY-MM-DDTHH:MM:SS
time_range_end =  '2016-10-15T00:00:00' # should match the notation YYYY-MM-DDTHH:MM:SS
platform_type = 'Oceanographic Buoy'
variables = 'sea_water_temperature'

# %%
min_lat = 40.0#float
max_lat = 38.0 #float
min_lon = 0.0 #float
max_lon = 3.0#float
bbox = str(min_lat)+','+str(max_lat)+','+str(min_lon)+','+str(max_lon)

# %%
end_point = '/data-sources/'
url_addons = '?platform_type=%s&initial_datetime=%s&end_datetime=%s&standard_variable=%s&bbox=%s'%(platform_type,time_range_start,time_range_end, variables,bbox)
request = requests.get('%s%s%s' % (api_url, end_point,url_addons), headers=headers)
response = json.loads(request.text)
print('Requested url: '+'%s%s%s' % (api_url, end_point,url_addons))
print(" ")
print('A total of %s SOCIB deployments match the above searching criteria'% (response['count']))
# Out:
# Requested url: http://api.socib.es/data-sources/?platform_type=Oceanographic Buoy&initial_datetime=2016-04-15T15:00:00&end_datetime=2016-10-15T00:00:00&standard_variable=sea_water_temperature&bbox=40.0,38.0,0.0,3.0
#
# A total of 12 SOCIB deployments match the above searching criteria

# %% [markdown]
# And choosing one of the above deployments, let's have a look to its metadata:

# %%
targeted_deployment = response['results'][2]#i.e deployment/data-source number 2 of the above page
metadata = {k:v for k, v in targeted_deployment.items() if k != 'entries'} #skipping the deployment data for later
HTML(json2html.convert(json=metadata))
# Out:
# <table border="1"><tr><th>status</th><td>completed</td></tr><tr><th>description</th><td>Conductivity and Temperature Recorder observational data</td></tr><tr><th>data_type</th><td>Time series</td></tr><tr><th>platform</th><td><table border="1"><tr><th>status</th><td>completed</td></tr><tr><th>wmo_naming_authority</th><td>JCOMMOBS</td></tr><tr><th>name</th><td>Buoy_CanalDeIbiza</td></tr><tr><th>initial_datetime</th><td>2013-07-01T00:00:00Z</td></tr><tr><th>end_datetime</th><td>2018-05-31T23:00:00Z</td></tr><tr><th>wmo_code</th><td>61141</td></tr><tr><th>type</th><td>Oceanographic Buoy</td></tr><tr><th>id</th><td>Buoy_CanalDeIbiza</td></tr></table></td></tr><tr><th>processing_levels</th><td><table border="1"><tr><th>L0</th><td><table border="1"><tr><th>variables</th><td><ul><li>sea_water_temperature</li><li>sea_water_pressure</li><li>sea_water_salinity</li><li>sea_water_electrical_conductivity</li></ul></td></tr></table></td></tr><tr><th>L1</th><td><table border="1"><tr><th>variables</th><td><ul><li>sea_water_temperature</li><li>sea_water_salinity</li><li>sea_water_electrical_conductivity</li></ul></td></tr></table></td></tr></table></td></tr><tr><th>name</th><td>Conductivity and Temperature Recorder observational data</td></tr><tr><th>instrument</th><td><table border="1"><tr><th>type</th><td><table border="1"><tr><th>type</th><td>Mooring</td></tr><tr><th>name</th><td>Conductivity and Temperature Recorder</td></tr></table></td></tr><tr><th>id</th><td>317</td></tr><tr><th>name</th><td>SCB-SBE37006</td></tr></table></td></tr><tr><th>update_datetime</th><td>2016-07-19T17:10:47Z</td></tr><tr><th>initial_datetime</th><td>2013-09-26T09:00:00Z</td></tr><tr><th>end_datetime</th><td>2016-07-19T15:25:00Z</td></tr><tr><th>coverage_bounding_box</th><td><table border="1"><tr><th>type</th><td>Polygon</td></tr><tr><th>coordinates</th><td><ul><li><ul><li><ul><li>0.783667</li><li>38.82445</li></ul></li><li><ul><li>0.783667</li><li>38.82445</li></ul></li><li><ul><li>0.783667</li><li>38.82445</li></ul></li><li><ul><li>0.783667</li><li>38.82445</li></ul></li><li><ul><li>0.783667</li><li>38.82445</li></ul></li></ul></li></ul></td></tr></table></td></tr><tr><th>type</th><td>observational</td></tr><tr><th>id</th><td>43043c50fd</td></tr><tr><th>feature_types</th><td><ul><li>timeSeries</li></ul></td></tr></table>

# %% [markdown]
# <h3>2. REQUEST ITS DATA</h3>

# %% [markdown]
# Let's choose one of the above L1 variables by means of <b>/data-sources/{id}/data/ </b> auxiliary endpoint:

# %%
end_point_plus_aux = '/data-sources/'+targeted_deployment['id']+'/data/?processing_level=L1&standard_variable=sea_water_temperature'
request = requests.get('%s%s' % (api_url, end_point_plus_aux), headers=headers)
response = json.loads(request.text)
print('Requested url: '+'%s%s' % (api_url, end_point_plus_aux))
# Out:
# Requested url: http://api.socib.es/data-sources/43043c50fd/data/?processing_level=L1&standard_variable=sea_water_temperature

# %%
def get_data_overview(response):
    #provides a quick glimse of a data-source variables overlooking its data values
    variable_metadata = {} 
    for level in response.keys():
        variable_metadata[level] = {}
        for item in response[level]['feature_types']:
            variable_metadata[level][item['feature_type']] = {}
            for standard_name in item['variables'].keys():
                variable_metadata[level][item['feature_type']][standard_name] = {}
                for var in item['variables'][standard_name].keys():
                    variable_metadata[level][item['feature_type']][standard_name][var] = {}
                    for key,value in item['variables'][standard_name][var].items():
                        if key != 'data':#overlooking data values
                            variable_metadata[level][item['feature_type']][standard_name][var][key] = value
    return variable_metadata

# %%
display(HTML(json2html.convert(json=get_data_overview(response))))
# Out:
# <table border="1"><tr><th>L1</th><td><table border="1"><tr><th>timeSeries</th><td><table border="1"><tr><th>sea_water_temperature</th><td><table border="1"><tr><th>WTR_TEM_SBE37</th><td><table border="1"><tr><th>axis_y_name</th><td>latitude</td></tr><tr><th>axis_z_name</th><td>depth</td></tr><tr><th>axis_x_name</th><td>longitude</td></tr><tr><th>precision</th><td>0.01</td></tr><tr><th>axis_t_name</th><td>time</td></tr><tr><th>long_name</th><td>Sea water temperature</td></tr><tr><th>standard_name</th><td>sea_water_temperature</td></tr><tr><th>units</th><td>C</td></tr></table></td></tr></table></td></tr></table></td></tr></table></td></tr></table>

# %% [markdown]
# <h3>3. PLOT ITS DATA</h3>

# %% [markdown]
# Let's have an quick overview of the complete deployment:

# %%
def get_matching_params(param, response):
    #returns matching params
    params = [] 
    for level in response.keys():
        for item in response[level]['feature_types']:
            for standard_name in item['variables'].keys():
                for var in item['variables'][standard_name].keys():
                    if var == param:
                        try:
                            params.append({'units':item['variables'][standard_name][var]['units'], 'data': item['variables'][standard_name][var]['data'], 'level': level, 'standard_name': standard_name, 'feature': item['feature_type'], 'name': param})
                        except:
                            params.append({'units': '-', 'data': item['variables'][standard_name][var]['data'], 'level': level, 'standard_name': standard_name, 'feature': item['feature_type'], 'name': param})
    return params

# %%
def get_matching_coords(coord,response):
    #returns matching coords
    coords = [] 
    for level in response.keys():
        for item in response[level]['feature_types']:
            for standard_name in item['coordinates'].keys():
                if standard_name == coord:
                    try:
                        coords.append({'units':item['coordinates'][standard_name]['units'], 'data': item['coordinates'][standard_name]['data'], 'level': level, 'standard_name': standard_name, 'feature': item['feature_type']})
                    except:
                        coords.append({'units': '-', 'data': item['coordinates'][standard_name]['data'], 'level': level, 'standard_name': standard_name, 'feature': item['feature_type']})
    return coords

# %%
params = get_matching_params('WTR_TEM_SBE37', response)
display(HTML(json2html.convert(json=[{k:v for k,v in param.items() if k!= 'data'} for param in params])))
# Out:
# <table border="1"><tr><th>units</th><th>feature</th><th>standard_name</th><th>name</th><th>level</th></tr><tr><td>C</td><td>timeSeries</td><td>sea_water_temperature</td><td>WTR_TEM_SBE37</td><td>L1</td></tr></table>

# %%
times = get_matching_coords('time', response)
display(HTML(json2html.convert(json=[{k:v for k,v in lon.items() if k!= 'data'} for lon in times])))
# Out:
# <table border="1"><tr><th>units</th><th>standard_name</th><th>feature</th><th>level</th></tr><tr><td>-</td><td>time</td><td>timeSeries</td><td>L1</td></tr></table>

# %% [markdown]
# Let's plot the only matching param:

# %%
var_values = np.array(params[0]['data'],dtype=float)
time_values = np.array(times[0]['data'])

# %%
var_units = params[0]['units']
var_std_name = params[0]['standard_name']
var_name = params[0]['name']

# %%
fig = plt.figure(figsize=(15, 8))
ax = fig.add_subplot(111)

time2 = [datetime.datetime.strptime(x, '%Y-%m-%dT%H:%M:%S') for x in time_values]
plt.plot(time2, var_values, color="teal", marker='o')
plt.ylabel(var_std_name+' ('+var_name+') ')
plt.xlabel('Year')
fig.autofmt_xdate()
plt.grid()
plt.show()

# %% [markdown]
# <h3>3. RESAMPLE ITS DATA</h3>

# %% [markdown]
# <ul><li><h3>RESAMPLE A DATA-SOURCE'S DATA BY <span>TIME WINDOW AND FORMULA </span></h3></li></ul>

# %% [markdown]
# Let's get the daily means from the above data:

# %%
resample_rule = 'D' 
resample_how ='mean'
end_point_plus_aux = '/data-sources/'+targeted_deployment['id']+'/data/?processing_level=L1&standard_variable=sea_water_temperature&max_qc_value=1&resample_how=%s&resample_rule=%s'%(resample_how, resample_rule)
request = requests.get('%s%s' % (api_url, end_point_plus_aux), headers=headers)
response = json.loads(request.text)
print('Requested url: '+'%s%s' % (api_url, end_point_plus_aux))
# Out:
# Requested url: http://api.socib.es/data-sources/43043c50fd/data/?processing_level=L1&standard_variable=sea_water_temperature&max_qc_value=1&resample_how=mean&resample_rule=D

# %%
display(HTML(json2html.convert(json=get_data_overview(response))))
# Out:
# <table border="1"><tr><th>L1</th><td><table border="1"><tr><th>timeSeries</th><td><table border="1"><tr><th>sea_water_temperature</th><td><table border="1"><tr><th>WTR_TEM_SBE37</th><td><table border="1"><tr><th>axis_y_name</th><td>latitude</td></tr><tr><th>axis_z_name</th><td>depth</td></tr><tr><th>axis_x_name</th><td>longitude</td></tr><tr><th>precision</th><td>0.01</td></tr><tr><th>axis_t_name</th><td>time</td></tr><tr><th>long_name</th><td>Sea water temperature</td></tr><tr><th>standard_name</th><td>sea_water_temperature</td></tr><tr><th>units</th><td>C</td></tr></table></td></tr></table></td></tr></table></td></tr></table></td></tr></table>

# %%
params = get_matching_params('WTR_TEM_SBE37', response)
display(HTML(json2html.convert(json=[{k:v for k,v in param.items() if k!= 'data'} for param in params])))
# Out:
# <table border="1"><tr><th>units</th><th>feature</th><th>standard_name</th><th>name</th><th>level</th></tr><tr><td>C</td><td>timeSeries</td><td>sea_water_temperature</td><td>WTR_TEM_SBE37</td><td>L1</td></tr></table>

# %%
times = get_matching_coords('time', response)
display(HTML(json2html.convert(json=[{k:v for k,v in lon.items() if k!= 'data'} for lon in times])))
# Out:
# <table border="1"><tr><th>units</th><th>standard_name</th><th>feature</th><th>level</th></tr><tr><td>-</td><td>time</td><td>timeSeries</td><td>L1</td></tr></table>

# %%
var_values = np.array(params[0]['data'],dtype=float)
time_values = np.array(times[0]['data'])

# %%
var_units = params[0]['units']
var_std_name = params[0]['standard_name']
var_name = params[0]['name']

# %%
fig = plt.figure(figsize=(15, 8))
ax = fig.add_subplot(111)
time2 = [datetime.datetime.strptime(x, '%Y-%m-%dT%H:%M:%S') for x in time_values]
plt.plot(time2, var_values, linewidth=2, color="teal", marker='o')
plt.ylabel(var_std_name+' ('+var_name+') ')
plt.xlabel('Year')
fig.autofmt_xdate()
plt.grid()
plt.show()

# %% [markdown]
# See more about resampling rules and methods (how) at: [pandas documentation](http://pandas.pydata.org/pandas-docs/stable/timeseries.html#offset-aliases)

# %% [markdown]
# <ul><li><h3>RESAMPLE A DATA-SOURCE'S DATA BY <span>QC FLAG</span></h3></li></ul>

# %% [markdown]
# Let's check a different the time range than the above defaulting one (last month of data):

# %%
end_point_plus_aux = '/data-sources/'+targeted_deployment['id']+'/data/?initial_datetime=2016-04-15T15:00:00&end_datetime=2016-10-15T00:00:00&processing_level=L1&standard_variable=sea_water_temperature'
request = requests.get('%s%s' % (api_url, end_point_plus_aux), headers=headers)
response = json.loads(request.text)
print('Requested url: '+'%s%s' % (api_url, end_point_plus_aux))
# Out:
# Requested url: http://api.socib.es/data-sources/43043c50fd/data/?initial_datetime=2016-04-15T15:00:00&end_datetime=2016-10-15T00:00:00&processing_level=L1&standard_variable=sea_water_temperature

# %%
display(HTML(json2html.convert(json=get_data_overview(response))))
# Out:
# <table border="1"><tr><th>L1</th><td><table border="1"><tr><th>timeSeries</th><td><table border="1"><tr><th>sea_water_temperature</th><td><table border="1"><tr><th>WTR_TEM_SBE37</th><td><table border="1"><tr><th>axis_y_name</th><td>latitude</td></tr><tr><th>axis_z_name</th><td>depth</td></tr><tr><th>axis_x_name</th><td>longitude</td></tr><tr><th>precision</th><td>0.01</td></tr><tr><th>axis_t_name</th><td>time</td></tr><tr><th>long_name</th><td>Sea water temperature</td></tr><tr><th>standard_name</th><td>sea_water_temperature</td></tr><tr><th>units</th><td>C</td></tr></table></td></tr></table></td></tr></table></td></tr></table></td></tr></table>

# %%
params = get_matching_params('WTR_TEM_SBE37', response)
display(HTML(json2html.convert(json=[{k:v for k,v in param.items() if k!= 'data'} for param in params])))
# Out:
# <table border="1"><tr><th>units</th><th>feature</th><th>standard_name</th><th>name</th><th>level</th></tr><tr><td>C</td><td>timeSeries</td><td>sea_water_temperature</td><td>WTR_TEM_SBE37</td><td>L1</td></tr></table>

# %%
times = get_matching_coords('time', response)
display(HTML(json2html.convert(json=[{k:v for k,v in lon.items() if k!= 'data'} for lon in times])))
# Out:
# <table border="1"><tr><th>units</th><th>standard_name</th><th>feature</th><th>level</th></tr><tr><td>-</td><td>time</td><td>timeSeries</td><td>L1</td></tr></table>

# %%
var_values = np.array(params[0]['data'],dtype=float)
time_values = np.array(times[0]['data'])

# %%
var_units = params[0]['units']
var_std_name = params[0]['standard_name']
var_name = params[0]['name']

# %%
fig = plt.figure(figsize=(15, 8))
ax = fig.add_subplot(111)
time2 = [datetime.datetime.strptime(x, '%Y-%m-%dT%H:%M:%S') for x in time_values]
plt.plot(time2, var_values, linewidth=2, color="red", marker='o')
plt.ylabel(var_std_name+' ('+var_name+') ')
plt.xlabel('Year')
fig.autofmt_xdate()
plt.grid()
plt.show()

# %% [markdown]
# QC flags allow users to target reliable data among all the available and overlook outliers such as the ones above. You can find out more about QC flags at [Ocean Sites](http://www.oceansites.org/docs/oceansites_data_format_reference_manual.pdf).

# %% [markdown]
# Let's just keep the data with QC flag 1 ('Good data') and plot the above time range again:

# %%
end_point_plus_aux = '/data-sources/'+targeted_deployment['id']+'/data/?initial_datetime=2016-03-21T15:00:00&end_datetime=2016-10-15T00:00:00&processing_level=L1&standard_variable=sea_water_temperature&max_qc_value=1'
request = requests.get('%s%s' % (api_url, end_point_plus_aux), headers=headers)
response = json.loads(request.text)
print('Requested url: '+'%s%s' % (api_url, end_point_plus_aux))
# Out:
# Requested url: http://api.socib.es/data-sources/43043c50fd/data/?initial_datetime=2016-03-21T15:00:00&end_datetime=2016-10-15T00:00:00&processing_level=L1&standard_variable=sea_water_temperature&max_qc_value=1

# %%
display(HTML(json2html.convert(json=get_data_overview(response))))
# Out:
# <table border="1"><tr><th>L1</th><td><table border="1"><tr><th>timeSeries</th><td><table border="1"><tr><th>sea_water_temperature</th><td><table border="1"><tr><th>WTR_TEM_SBE37</th><td><table border="1"><tr><th>axis_y_name</th><td>latitude</td></tr><tr><th>axis_z_name</th><td>depth</td></tr><tr><th>axis_x_name</th><td>longitude</td></tr><tr><th>precision</th><td>0.01</td></tr><tr><th>axis_t_name</th><td>time</td></tr><tr><th>long_name</th><td>Sea water temperature</td></tr><tr><th>standard_name</th><td>sea_water_temperature</td></tr><tr><th>units</th><td>C</td></tr></table></td></tr></table></td></tr></table></td></tr></table></td></tr></table>

# %%
params = get_matching_params('WTR_TEM_SBE37', response)
display(HTML(json2html.convert(json=[{k:v for k,v in param.items() if k!= 'data'} for param in params])))
# Out:
# <table border="1"><tr><th>units</th><th>feature</th><th>standard_name</th><th>name</th><th>level</th></tr><tr><td>C</td><td>timeSeries</td><td>sea_water_temperature</td><td>WTR_TEM_SBE37</td><td>L1</td></tr></table>

# %%
times = get_matching_coords('time', response)
display(HTML(json2html.convert(json=[{k:v for k,v in lon.items() if k!= 'data'} for lon in times])))
# Out:
# <table border="1"><tr><th>units</th><th>standard_name</th><th>feature</th><th>level</th></tr><tr><td>-</td><td>time</td><td>timeSeries</td><td>L1</td></tr></table>

# %%
var_values = np.array(params[0]['data'],dtype=float)
time_values = np.array(times[0]['data'])

# %%
var_units = params[0]['units']
var_std_name = params[0]['standard_name']
var_name = params[0]['name']

# %%
fig = plt.figure(figsize=(15, 8))
ax = fig.add_subplot(111)
time2 = [datetime.datetime.strptime(x, '%Y-%m-%dT%H:%M:%S') for x in time_values]
plt.plot(time2, var_values, linewidth=2, color="teal", marker='o')
plt.ylabel(var_std_name+' ('+var_name+') ')
plt.xlabel('Year')
fig.autofmt_xdate()
plt.grid()
plt.show()
