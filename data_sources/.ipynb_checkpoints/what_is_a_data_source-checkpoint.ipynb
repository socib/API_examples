# %% [markdown]
# <h1 class="header"><img class="logo" src="../images/socib_logo.png" width="200px"></h1>

# %% [markdown]
# <h3> STYLING NOTEBOOK (OPTIONAL)</h3>

# %%
from IPython.core.display import HTML
import urllib
HTML(urllib.urlopen('https://raw.githubusercontent.com/socib/API_examples/master/style/custom/custom.css').read())
# Out:
# <style>
#
# h1{
# 	float:right !important
# }
#
# h1>img{
# 	width: 200px !important
# }
#
# h3{
# 	background-color: #00334C;
# 	border: 1px solid #e3e3e3;
# 	border-radius: 4px;
# 	color: #3dabb6;
# 	padding: 19px
# }
#
# h3>span{
# 	border: 1px solid #3dabb6;
# 	border-radius: 4px;
# 	background-color: #3dabb6;
# 	color: white;
# 	padding: 5px
# }
#
# ul>li>b{
# 	border: 1px solid #3dabb6;
# 	border-radius: 4px;
# 	background-color: #3dabb6;
# 	color: white; padding: 5px;
# }
# </style>

# %% [markdown]
# <h3>HANDY PYTHON PACKAGES</h3>

# %%
import numpy as np
import requests
import json
import urllib
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
from matplotlib.patches import Polygon
from json2html import *
from IPython.display import HTML
import os
# %matplotlib inline

# %% [markdown]
# <h3>PREREQUISITES</h3>

# %%
api_key = '' #write you SOCIB api_key
api_url = 'http://api.socib.es'
headers = {
    'accept': 'application/vnd.socib+json',
    'apikey': api_key,
}

# %% [markdown]
# <h3> WHAT ARE EXACTLY DATA-SOURCES?</h3>

# %% [markdown]
# SOCIB Data-sources represents the so-called <i>deployments</i>. A deployment is an instrument&platform enssemble deployed (placed or released) to retrieve data from the ocean. During the time period this combo is active, the data measured by it is said to belong to the same deployment (same intrument&platform enssemble -> same constrains) and therefore grouped together. This way, deployments have stand-out as the basic unit of organization for oceanographic data and SOCIB archiving reflects this policy.

# %% [markdown]
# For example, see here the deployment of a platform (an Oceanographic buoy) with all its instruments: wave recorder, weather station, conductivity and temperature recorder, currentemeter, current profiler ...
# <img src="../images/deployment_ocenographic_buoy.jpg">

# %% [markdown]
# <h3>WHICH ENDPOINT DO I USE TO EXPLORE SOCIB DATA-SOURCES?</h3>

# %% [markdown]
# As we already saw in [Quick start](../tips/quick_start.ipynb) there is an ENDPOINT that allows users to dive into all the data-sources (deployments) that SOCIB has ever performed:

# %%
end_point = '/data-sources/'
request = requests.get('%s%s' % (api_url, end_point), headers=headers)
response = json.loads(request.text)

print('Requested url: '+'%s%s' % (api_url, end_point))
print('SOCIB has performed so far a total of %s deployments'%(response['count']))
# Out:
# Requested url: http://api.socib.es/data-sources/
# SOCIB has performed so far a total of 839 deployments

# %% [markdown]
# <h3>HOW DOES IT WORKS?</h3>

# %% [markdown]
# Regarding the data-sources, the API resembles a catalogue that someone can read-trough; with a number of pages to turn and, as content of such pages, a number of deployments:

# %%
print('Catalogue total number of pages: '+str((response['count']/len(response['results']))+1))
# Out:
# Catalogue total number of pages: 105

# %%
print('Number of deployments per page: '+str(len(response['results'])))
# Out:
# Number of deployments per page: 8

# %% [markdown]
# <h3>OVERVIEW OF A GIVEN DATA-SOURCE - <span> DEPLOYMENT'S METADATA </span></h3>

# %% [markdown]
# Imagine you are on page 10 of the data-sources catalogue:

# %%
end_point = '/data-sources/?page=10'
request = requests.get('%s%s' % (api_url, end_point), headers=headers)
response = json.loads(request.text)
print('Requested url: '+'%s%s' % (api_url, end_point))
print('Next url: '+response['next'])
print('Previous url: '+response['previous'])
# Out:
# Requested url: http://api.socib.es/data-sources/?page=10
# Next url: http://api.socib.es/data-sources/?page=11
# Previous url: http://api.socib.es/data-sources/?page=9

# %% [markdown]
# Each data-source (stored as <b>'results'</b> in the response of the above query), is uniquely identified by 13 properties: <i>name, coverage_bounding_box, type, id, status, description, data_type, instrument, platform, update_time, initial_time, end_time & processing levels</i>.<br>
# Let's have a look to the metadata of one of the data-sources:

# %%
targeted_deployment = response['results'][5]#i.e deployment/data-source number 5 of the above page
metadata = {k:v for k, v in targeted_deployment.items() if k != 'entries'} #skipping the deployment data for later
HTML(json2html.convert(json=metadata))
# Out:
# <table border="1"><tr><th>status</th><td>active</td></tr><tr><th>description</th><td>Currentmeter observational data</td></tr><tr><th>data_type</th><td>Time series</td></tr><tr><th>platform</th><td><table border="1"><tr><th>status</th><td>active</td></tr><tr><th>wmo_naming_authority</th><td>JCOMMOBS</td></tr><tr><th>name</th><td>Buoy_BahiaDePalma</td></tr><tr><th>initial_datetime</th><td>2011-06-16T00:30:00Z</td></tr><tr><th>end_datetime</th><td>2018-11-30T10:30:00Z</td></tr><tr><th>wmo_code</th><td>61499</td></tr><tr><th>type</th><td>Oceanographic Buoy</td></tr><tr><th>id</th><td>Buoy_BahiaDePalma</td></tr></table></td></tr><tr><th>processing_levels</th><td><table border="1"><tr><th>L0</th><td><table border="1"><tr><th>variables</th><td><ul><li>direction_of_sea_water_velocity</li><li>platform_tilt</li><li>sea_water_speed</li><li>platform_orientation</li><li>northward_sea_water_velocity</li><li>voltage</li><li>eastward_sea_water_velocity</li><li>sea_water_temperature</li><li>speed_of_sound_in_sea_water</li></ul></td></tr></table></td></tr><tr><th>L1</th><td><table border="1"><tr><th>variables</th><td><ul><li>direction_of_sea_water_velocity</li><li>platform_tilt</li><li>sea_water_speed</li><li>platform_orientation</li><li>northward_sea_water_velocity</li><li>voltage</li><li>eastward_sea_water_velocity</li><li>sea_water_temperature</li><li>speed_of_sound_in_sea_water</li></ul></td></tr></table></td></tr></table></td></tr><tr><th>name</th><td>Currentmeter observational data</td></tr><tr><th>instrument</th><td><table border="1"><tr><th>type</th><td><table border="1"><tr><th>type</th><td>Mooring</td></tr><tr><th>name</th><td>Currentmeter</td></tr></table></td></tr><tr><th>id</th><td>385</td></tr><tr><th>name</th><td>SCB-FSI003</td></tr></table></td></tr><tr><th>update_datetime</th><td>2018-11-30T10:30:22Z</td></tr><tr><th>initial_datetime</th><td>2018-02-16T14:00:00Z</td></tr><tr><th>end_datetime</th><td>2018-11-30T10:25:00Z</td></tr><tr><th>coverage_bounding_box</th><td><table border="1"><tr><th>type</th><td>Polygon</td></tr><tr><th>coordinates</th><td><ul><li><ul><li><ul><li>2.700405</li><li>39.492848</li></ul></li><li><ul><li>2.700405</li><li>39.492848</li></ul></li><li><ul><li>2.700405</li><li>39.492848</li></ul></li><li><ul><li>2.700405</li><li>39.492848</li></ul></li><li><ul><li>2.700405</li><li>39.492848</li></ul></li></ul></li></ul></td></tr></table></td></tr><tr><th>type</th><td>observational</td></tr><tr><th>id</th><td>d06d59e27f</td></tr><tr><th>feature_types</th><td><ul><li>timeSeries</li></ul></td></tr></table>

# %% [markdown]
# Depending on the nature of the platform composing the deployment enssemble (instrument & platfrom) a data-source can be mobile or fixed and therefore the resulting deployment's coverage will be reduced to a point (case of moorings) or to a polygon (case of drifters, profilers, vessels etc). <br>Let's have a look to the present one:

# %%
fig = plt.figure(figsize=(20,16))
m = Basemap(projection='merc', llcrnrlat=30., urcrnrlat=46.,llcrnrlon=-10, urcrnrlon=40., lat_ts=38., resolution='l')
m.fillcontinents(zorder=2)
m.drawparallels(np.arange(-90.,91.,2.), labels=[1,0,0,0], linewidth=0.5, zorder=1, fontsize=20)
m.drawmeridians(np.arange(-180.,181.,3.), labels=[0,0,1,0], linewidth=0.5, zorder=1, fontsize=20)
lats = [item[1] for item in targeted_deployment['coverage_bounding_box']['coordinates'][0]]
lons = [item[0] for item in targeted_deployment['coverage_bounding_box']['coordinates'][0]]
x,y = m( lons, lats )
if all(targeted_deployment['coverage_bounding_box']['coordinates'][0][0] == item for item in targeted_deployment['coverage_bounding_box']['coordinates'][0]):
    m.plot(x, y, 'ro', markersize=4)
else:
    #mobile platforms
    xy = zip(x,y)
    poly = Polygon( xy, facecolor='white', edgecolor='red', alpha=0.4, linewidth=2,zorder=3)
    plt.gca().add_patch(poly)

plt.title(metadata['platform']['name']+' deployment coverage ('+metadata['platform']['type']+')', fontsize=20, y=1.1)

# %% [markdown]
# On the data-source overview the variables measured by the deployment are grouped in the different processing levels:
# <ul>
#     <li>L0: raw data</li>
#     <li>L1: data with quality flags (data classified as good, bad, potentially good etc) </li>
#     <li>L2: derived product (i.e vertical profiles form gliders) </li>
# </ul>
# <br>
# This way, when a variable is available in more than one processing level it is up to the user choosing the most suitable one regarding the work to be done (validation, assimilation etc).

# %% [markdown]
# <h3>DATA FROM A GIVEN DATA-SOURCE - <span> DEPLOYMENT'S NETCDFS</span></h3>

# %% [markdown]
# Each data-source's data is a collection of netCDFS stored as <b>'entries'</b>:

# %%
targeted_deployment = response['results'][0]#i.e deployment number 0 of the above page
data = {k:v for k, v in targeted_deployment.items() if k == 'entries'} #choosing just the deployment data
print('The deployment targeted produced %s netCDFs' % (len(data['entries'])))
# Out:
# The deployment targeted produced 24 netCDFs

# %% [markdown]
# Each so-called 'entry' (netCDF) is uniquely identified by a serie of properties: <i> name, last_update, initial_datetime, end_datetime, services, viewers and processing_level.</i><br>Let's explore one of the entries (netCDF) from the above data-source:

# %%
targeted_deployment = response['results'][5]#i.e deployment number 0 of the above page
data = {k:v for k, v in targeted_deployment.items() if k == 'entries'} #choosing just the deployment data
targeted_netCDF = 0 #i.e netCDF number 0 of the above deployment
HTML(json2html.convert(json=data['entries'][targeted_netCDF]))
# Out:
# <table border="1"><tr><th>name</th><td>data from 2018-11-01 00:25:00+00:00 to 2018-11-30 10:25:00+00:00</td></tr><tr><th>last_update</th><td>2018-11-30 10:30:21+00:00</td></tr><tr><th>initial_datetime</th><td>2018-11-01 00:25:00+00:00</td></tr><tr><th>end_datetime</th><td>2018-11-30 10:25:00+00:00</td></tr><tr><th>services</th><td><table border="1"><tr><th>http_file</th><td><table border="1"><tr><th>url</th><td>http://thredds.socib.es/thredds/fileServer/mooring/currentmeter/buoy_bahiadepalma-scb_fsi003/L0/2018/dep0002_buoy-bahiadepalma_scb-fsi003_L0_2018-11.nc</td></tr></table></td></tr><tr><th>opendap</th><td><table border="1"><tr><th>url</th><td>http://thredds.socib.es/thredds/dodsC/mooring/currentmeter/buoy_bahiadepalma-scb_fsi003/L0/2018/dep0002_buoy-bahiadepalma_scb-fsi003_L0_2018-11.nc</td></tr></table></td></tr><tr><th>thredds_catalog</th><td><table border="1"><tr><th>url</th><td>http://thredds.socib.es/thredds/catalog/mooring/currentmeter/buoy_bahiadepalma-scb_fsi003/L0/2018/catalog.html?dataset=mooring/currentmeter/buoy_bahiadepalma-scb_fsi003/L0/2018/dep0002_buoy-bahiadepalma_scb-fsi003_L0_2018-11.nc</td></tr></table></td></tr></table></td></tr><tr><th>viewers</th><td><table border="1"><tr><th>jwebchart</th><td><table border="1"><tr><th>url</th><td>http://www.socib.es/jwebchart/?file=http://thredds.socib.es/thredds/dodsC/mooring/currentmeter/buoy_bahiadepalma-scb_fsi003/L0/2018/dep0002_buoy-bahiadepalma_scb-fsi003_L0_2018-11.nc</td></tr></table></td></tr></table></td></tr><tr><th>processing_level</th><td>L0</td></tr></table>

# %% [markdown]
# As we saw before, the data measured by a deployment is tied together as a netCDF file collection at SOCIB archiving. Commited to an Open Access Policy, SOCIB distributes these netCDFs through a THREDDS data server. These servers maps the available netCDFs and provide several services and viewers for it to be downloaded (http_file), accessed (opendap) and explored (viewers). <br>See some above.

# %% [markdown]
# Let's for example use the http_file option for downloading:

# %%
path = os.getcwd() #set the path you want the files to endup. Working directory as default one.

# %%
netCDFs_http_files = [entry['services']['http_file']['url'] for entry in targeted_deployment['entries']]
for nc in netCDFs_http_files:
    nc_name =  nc[nc.rfind('/')+1:]
    urllib.urlretrieve (nc, path+'/'+nc_name)
    print(nc_name)
# Out:
# dep0002_buoy-bahiadepalma_scb-fsi003_L0_2018-11.nc
# dep0002_buoy-bahiadepalma_scb-fsi003_L1_2018-11.nc
# dep0002_buoy-bahiadepalma_scb-fsi003_L1_2018-10.nc
# dep0002_buoy-bahiadepalma_scb-fsi003_L1_2018-09.nc
# dep0002_buoy-bahiadepalma_scb-fsi003_L1_2018-08.nc
# dep0002_buoy-bahiadepalma_scb-fsi003_L1_2018-07.nc
# dep0002_buoy-bahiadepalma_scb-fsi003_L1_2018-06.nc
# dep0002_buoy-bahiadepalma_scb-fsi003_L1_2018-05.nc
# dep0002_buoy-bahiadepalma_scb-fsi003_L1_2018-04.nc
# dep0002_buoy-bahiadepalma_scb-fsi003_L1_2018-03.nc
# dep0002_buoy-bahiadepalma_scb-fsi003_L1_2018-02.nc
# dep0002_buoy-bahiadepalma_scb-fsi003_L0_2018-10.nc
# dep0002_buoy-bahiadepalma_scb-fsi003_L0_2018-09.nc
# dep0002_buoy-bahiadepalma_scb-fsi003_L0_2018-08.nc
# dep0002_buoy-bahiadepalma_scb-fsi003_L0_2018-07.nc
# dep0002_buoy-bahiadepalma_scb-fsi003_L0_2018-06.nc
# dep0002_buoy-bahiadepalma_scb-fsi003_L0_2018-05.nc
# dep0002_buoy-bahiadepalma_scb-fsi003_L0_2018-04.nc
# dep0002_buoy-bahiadepalma_scb-fsi003_L0_2018-03.nc
# dep0002_buoy-bahiadepalma_scb-fsi003_L0_2018-02.nc

# %% [markdown]
# All the services linked to THREDDS orbits around the netCDFs and in the end this implies a certain level of knowledge about such format to properly retrieve a given deployment data. Nevertheless, SOCIB API offers auxiliary endpoints that serve a data-source's data straightway and abstract the user from any underlying format. In next notebooks we will have a look to such auxiliary endpoints.

# %% [markdown]
# <h3>DETAILED VIEW OF A GIVEN DATA-SOURCE - <span> SHORTCUT TO A KNOWN DEPLOYMENT </span></h3>

# %% [markdown]
# We have found and explored the above deployment by targeting an specific page number and position on this page, but this whole searching process can be skipped onwards by preserving its id:

# %%
end_point = '/data-sources/'+targeted_deployment['id']
request = requests.get('%s%s' % (api_url, end_point), headers=headers)
response = json.loads(request.text)
print('Requested url: '+'%s%s. Be aware of the id.' % (api_url, end_point))
# Out:
# Requested url: http://api.socib.es/data-sources/d06d59e27f. Be aware of the id.

# %%
targeted_deployment = response
metadata = {k:v for k, v in targeted_deployment.items() if k != 'entries'} #skipping the deployment data for later
HTML(json2html.convert(json=metadata))
# Out:
# <table border="1"><tr><th>status</th><td>active</td></tr><tr><th>description</th><td>Currentmeter observational data</td></tr><tr><th>data_type</th><td>Time series</td></tr><tr><th>platform</th><td><table border="1"><tr><th>status</th><td>active</td></tr><tr><th>wmo_naming_authority</th><td>JCOMMOBS</td></tr><tr><th>name</th><td>Buoy_BahiaDePalma</td></tr><tr><th>initial_datetime</th><td>2011-06-16T00:30:00Z</td></tr><tr><th>end_datetime</th><td>2018-11-30T10:30:00Z</td></tr><tr><th>wmo_code</th><td>61499</td></tr><tr><th>type</th><td>Oceanographic Buoy</td></tr><tr><th>id</th><td>Buoy_BahiaDePalma</td></tr></table></td></tr><tr><th>processing_levels</th><td><table border="1"><tr><th>L0</th><td><table border="1"><tr><th>variables</th><td><ul><li>direction_of_sea_water_velocity</li><li>platform_tilt</li><li>sea_water_speed</li><li>platform_orientation</li><li>northward_sea_water_velocity</li><li>voltage</li><li>eastward_sea_water_velocity</li><li>sea_water_temperature</li><li>speed_of_sound_in_sea_water</li></ul></td></tr></table></td></tr><tr><th>L1</th><td><table border="1"><tr><th>variables</th><td><ul><li>direction_of_sea_water_velocity</li><li>platform_tilt</li><li>sea_water_speed</li><li>platform_orientation</li><li>northward_sea_water_velocity</li><li>voltage</li><li>eastward_sea_water_velocity</li><li>sea_water_temperature</li><li>speed_of_sound_in_sea_water</li></ul></td></tr></table></td></tr></table></td></tr><tr><th>name</th><td>Currentmeter observational data</td></tr><tr><th>instrument</th><td><table border="1"><tr><th>type</th><td><table border="1"><tr><th>type</th><td>Mooring</td></tr><tr><th>name</th><td>Currentmeter</td></tr></table></td></tr><tr><th>id</th><td>385</td></tr><tr><th>name</th><td>SCB-FSI003</td></tr></table></td></tr><tr><th>update_datetime</th><td>2018-11-30T10:30:22Z</td></tr><tr><th>initial_datetime</th><td>2018-02-16T14:00:00Z</td></tr><tr><th>end_datetime</th><td>2018-11-30T10:25:00Z</td></tr><tr><th>coverage_bounding_box</th><td><table border="1"><tr><th>type</th><td>Polygon</td></tr><tr><th>coordinates</th><td><ul><li><ul><li><ul><li>2.700405</li><li>39.492848</li></ul></li><li><ul><li>2.700405</li><li>39.492848</li></ul></li><li><ul><li>2.700405</li><li>39.492848</li></ul></li><li><ul><li>2.700405</li><li>39.492848</li></ul></li><li><ul><li>2.700405</li><li>39.492848</li></ul></li></ul></li></ul></td></tr></table></td></tr><tr><th>type</th><td>observational</td></tr><tr><th>id</th><td>d06d59e27f</td></tr><tr><th>feature_types</th><td><ul><li>timeSeries</li></ul></td></tr></table>

# %% [markdown]
# <h3>WHAT ELSE?</h3>

# %% [markdown]
# <ul>
# <li><b>SEARCHING FOR CERTAIN DATA-SOURCES</b> <br><br>If you want to retrieve only those SOCIB data-sources matching certain criteria, please have a look at the [Example 2](searching_for_certain_data_sources.ipynb) ('Searching for certain data-sources'), where it is explained how to set a searching criteria over the generic /data-source/ ENDPOINT to filter the available data-sources according to your needs.</li>
# <br>
# <li><b>REQUESTING A DATA-SOURCE'S DATA </b> <br><br> If you want to know more about how to access a given data-source's data overlooking the netCDF format, please have a look at the [Example 3](requesting_a_data_sources_data.ipynb) ('Accessing the data of a data-source'), where it is explained how to use auxiliary endpoints to request a deployments data.</li>
# <br>
# <li><b>SUBSETTING A DATA-SOURCE'S DATA </b> <br><br>If you want to know more about how to subset a given data-source's data overlooking the netCDF format, please have a look at the [Example 4](subsetting_a_data_sources_data.ipynb) ('Subsetting a data-source's data'), where it is explained how to use query parameters over the API auxiliary endpoints to subset a deployments data.</li>
# <br>
# <li><b>RESAMPLING A DATA-SOURCE'S DATA </b> <br><br>If you want to know more about how to resample a given data-source's data overlooking the netCDF format, please have a look at the [Example 5](resampling_a_data_sources_data.ipynb) ('Resampling a data-source's data'), where it is explained how to use query parameters over the API auxiliary endpoints to resample a deployments data.</li>
# </ul>
